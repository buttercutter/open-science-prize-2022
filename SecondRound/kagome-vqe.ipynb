# %% [markdown]
# # 1 Introduction
# ## 1-1 Quantum State Preparation
# Quantum state preparation is fundamental to quantum computing. It lies at the heart of quantum algorithms, quantum machine learning, quantum error correction, and quantum physics research, but it can be very difficult to start from an initial state $|0\dots 0 \rangle$ and efficiently prepare an arbitrary state $|\psi \rangle$ with high fidelity. Your objective for this year's Open Science Prize is to significantly improve state-of-the-art state preparation in the context of the Variational Quantum Eigensolver (VQE) algorithm.
#
# The state you will prepare is the highly entangled ground state of a Heisenberg spin-1/2 model on a kagome lattice. That sentence is jam packed with physics jargon, but do not despair. Though the problem statement originates deep within quantum physics research, we will avoid jargon as much as possible. A deep dive into the physics literature (which is very fascinating) is left as an exercise for the reader.
#
# Why the ground state of a Heisenberg model? Well, the ground state of a system is it's lowest energy configuration, and the ground state tends to be where exciting and unexpected quantum affects flourish. For example, when the element Mercury is cooled down near its ground state (below 4 Kelvin), it has no electrical resistance. None. Zero! Near its thermal ground state, a chunk of Mercury is [a superconductor](https://en.wikipedia.org/wiki/History_of_superconductivity). Researchers have been trying to understand what materials exhibit superconductivity and how it's even possible ever since it was first discovered. If that isn't cool enough for you, consider the [Bose-Einstein condensate](https://en.wikipedia.org/wiki/Bose–Einstein_condensate). This is quantum phase of matter where a dilute gas of individual atoms (bosonic atoms such as [Rubidium](https://en.wikipedia.org/wiki/Rubidium))--when cooled to their ground state--effectively become one giant particle!
#
# A system's ground state determines important and fascinating physical properties (see the two examples highlighted above), yet some quantum systems have ground states (and their associated energies) which are difficult to make and measure in the lab as well as being intractable for classical computers to calculate. The Variational Quantum Eigensolver (VQE) is a promising quantum algorithm that could find these ground states and their energies.
#
# You will implement the VQE algorithm on [ibmq_guadalupe](https://quantum-computing.ibm.com/services/resources?system=ibmq_guadalupe) a 16 qubit [heavy-hex](https://research.ibm.com/blog/heavy-hex-lattice) device. This is the largest device used in an Open Science Prize to date. Working with more qubits presents its own challenges. Be mindful of how your solution scales as this will be part of the judging criteria this year.
#
# We'll get more into the principles of VQE later, but for now, remember that VQE relies on iterative cycles of quantum and classical computation. Fast iterations and fast communication between the classical and quantum computer are essential for a fast VQE, and [Qiskit runtime](https://github.com/Qiskit/qiskit-ibm-runtime) does just that. [Qiskit runtime](https://medium.com/qiskit/so-what-is-qiskit-runtime-anyway-c78aecf3742) is a programming model and containerized environment designed to reduce the computational cycle time between quantum and classical computers. Later in this notebook, we will demonstrate how to leverage the latest release of runtime for fast VQE.
#
# The notebook is organized as follows: Section 1 gives a brief introduction to the Heisenberg model, the kagome lattice, and VQE algorithm. It also provides a classical calculation of the ground state(s) energy. Section 2 introduces how to construct a VQE experiment and simulate it on your local computer. Section 3 introduces Qiskit runtime and how to run VQE on a cloud simulator or real backend. Finally, if you are feeling stuck, we've provided some questions to consider as you design and implement your solution.
#
# #### Objective
# **Your task is to use the VQE algorithm to compute the ground state of a Heisenberg spin-1/2 system on a kagome lattice unit cell with the lowest possible relative error of the measured state's energy expectation value wrt to the exact value.** There are actually two ground states in this specific case, and you may prepare any combination of the two including only one or the other.

# %% [markdown]
# ## 1-2 Heisenberg spin-1/2 model on the kagome lattice
# For the Open Science Prize, (get ready for some jargon) you will work with the antiferromagnetic $XXX$ Heisenberg model arranged on a kagome lattice. The $XXX$ Heisenberg model Hamiltonian for this Prize will be defined as
# $$
# \begin{equation}
# H = \sum_{\langle i j \rangle}^N X_i X_{j} + Y_i Y_{j} + Z_i Z_{j}
# \end{equation}
# $$
# where $\langle i j \rangle$ is sum over neighboring spins and $X$, $Y$, and $Z$ are the usual Pauli matrices. The Heisenberg model hosts a wide variety of exotic quantum physics all of which heavily depend on the arrangement of the spins. The arrangement we are interested in is a kagome lattice.
#
# ![title](kagome_unit_cell.png)
#
# The kagome lattice is a unique lattice structure made up of corner-sharing triangles (see the unit cell above). In general, the kagome lattice (i.e. many unit cells tiled together) is theorized to host a fascinating quantum phase of matter called a quantum spin liquid--a research topic at the forefront of quantum physics [1-3]. Additionally, excitations from that ground state are theorized to show exotic quantum behavior such a fractionalized particle excitations [1-3]. For those interested in a deeper dive into the physics check out Refs. [1-3] and other papers.
#
# This year's Prize will focus on a single unit cell (the base pattern shown above) which has 12 spin-1/2 particles represented in as blue dots in the image below. Each spin will be represented by a single qubit. The lines connecting the spin-1/2 particles called edges--borrowing a term from [graph theory](https://en.wikipedia.org/wiki/Graph_theory)--and they specify which spins are neighbors.
#
# \[1\] "Modern condensed matter physics." Girvin, Steven M., and Kun Yang. Cambridge University Press, (2019).
#
# \[2\] "Spin liquids in frustrated magnets." Balents, Leon. [Nature 464, 199–208](https://doi.org/10.1038/nature08917) (2010).
#
# \[3\] "Probing topological spin liquids on a programmable quantum simulator." Semeghini, Giulia, et al. [Science 374.6572: 1242-1247.](https://www.science.org/doi/10.1126/science.abi8794) (2021). [arXiv link](https://arxiv.org/abs/2104.04119)
#
# \[4\] "Kagome: The Story of the Basketweave Lattice." Mekata, Mamoru. [Physics Today 56, 2, 12](https://physicstoday.scitation.org/doi/10.1063/1.1564329) (2003).

# %% [markdown]
# ## 1-3 VQE
# The Variational Quantum Eigensolver (VQE) is a quantum algorithm that can find the ground state(s) of a given Hamiltonian [5-7]. The VQE algorithm is based on the [variational principle](https://en.wikipedia.org/wiki/Variational_method_(quantum_mechanics)) of quantum mechanics and relies on both quantum and classical computations. Below, we briefly sketch out the main principles of VQE, and encourage you to review educational material and the research literature for details.
#
# Given a Hamiltonian $H$ and ground state $|\psi_g \rangle$, the variational principle says that even if we don't know the exact ground state an approximate ground state $|\tilde{ \psi}_g\rangle \approx |\psi_g \rangle$ can be found. To find the approximate ground state $|\tilde{ \psi}_g\rangle$, we start with a parameterized state called an ansatz $|\psi(\boldsymbol{\theta})\rangle$ where $\boldsymbol{\theta} \equiv (\theta_1, \theta_2,\dots)$ are the parameters. In theory, there is a combination of parameter values where the anstaz approximates the ground state $|\psi(\boldsymbol{\theta})\rangle \approx |\psi_g\rangle$, but we need a way to find those parameter values. This is done with a combination of quantum and classical computing.
#
# To optimize the parameters, many cycles of quantum and classical computing drive the ansatz toward the approximate ground state. The quantum computer computes the energy expectation value of Hamiltonian $H$ acting on the the parameterized anstaz for a given set of parameter values
# $$
# E(\boldsymbol{\theta}) = \langle \psi(\boldsymbol{\theta}) | H | \psi(\boldsymbol{\theta}) \rangle \;.
# $$
# For those familiar with optimization terminology this is the cost function. A classical computer uses the measurement data from the quantum computer to determine how the parameters values should be adjusted to further minimize the energy $E(\boldsymbol{\theta})$. As the classical and quantum computer loop through many iterations, they search the parameter space and converge to the approximate ground state.
#
# How can we know the state that gives the minimum energy expectation value is the ground state? The variation principle guarantees that the minimal energy expectation value can only be achieved if the quantum state is the ground state. No other state can give a lower energy--hence the name ground state. In this way, we can be confident that minimizing $E(\boldsymbol{\theta})$ with respect to the parameters $\boldsymbol{\theta}$ will drive the ansatz toward an accurate approximation of the true ground state and not some other state.
#
# Of course, the actual implementation of the algorithm comes with challenges. The ansatz $|\psi(\boldsymbol{\theta})\rangle$ may never reach the ground state for any combination of parameters. The ansatz could have too many parameters and encounter a barren plateau during optimization. When implementing the VQE, it may take an unreasonable amount of time to execute the ansatz or measure the expectation value on quantum hardware. The quantum hardware may be too noisy. The classical optimizer may not pair well with the optimization landscape or the level of noise from the quantum measurements. Etc.
#
# To jump into more details about VQE, we included three review articles on the topic below. We encourage you to review additional educational material and research literature as you work out your solution.
#
# \[5\] "A variational eigenvalue solver on a quantum processor." A. Peruzzo, et al. [arXiv:1304.3061](https://arxiv.org/abs/1304.3061) [quant-ph] (2013).
#
# \[6\] "Variational quantum algorithms." M. Cerezo, et al. [arXiv:2012.09265v2](https://arxiv.org/abs/2012.09265v2) [quant-ph] (2021).
#
# \[7\] "The Variational Quantum Eigensolver: a review of methods and best practices." J. Tilly, et al. [arXiv:2111.05176v3](https://arxiv.org/abs/2111.05176v3) [quant-ph] (2022).

# %%
import numpy as np

from time import time

import matplotlib.pyplot as plt
plt.rcParams.update({"font.size": 16})  # enlarge matplotlib fonts

# %% [markdown]
# ## 1-4 Classical computation of ground state energy
# The twelve qubit state space isn't terribly large $2^{12} = 4096$, but it also isn't small. A classical computer can still diagonalize the Hamiltonian and thus compute the ground state and its associated energy. For the Open Science Prize, we don't need a full energy spectrum, just a calculation of the ground state energy. When working on your solution, remember that brute force approaches that work on 5 or 7-qubit devices may not work as well with ibmq_guadalupe's 16 qubits.
#
# Below is an example classical calculation of the ground state energy. It will be used as a reference to your VQE results. First, the kagome lattice is defined on a graph. Second, we built the Hamiltonian from the graph edges. Finally, the expected ground state energy is calculated.
#
# ### Qiskit nature kagome unit cell
# Using Qiskit nature's [`Lattice` object](https://qiskit.org/documentation/nature/tutorials/10_lattice_models.html), we can represent any spin lattice as a graph. Here we construct the unit cell of a kagome lattice by defining a list of edges between the twelve sites. This `Lattice` representation will be convenient to use when defining the $XXX$ Hamiltonian terms.

# %%
import rustworkx as rx

from qiskit_nature.problems.second_quantization.lattice import Lattice

# Custom Heisenberg couplings
import sys
sys.path.append(r'.')  # may be needed if running notebook on a cloud service
from heisenberg_model import HeisenbergModel

# %%
# Kagome unit cell
num_sites = 12
# Edge weight
t = 1.0

# Generate graph of kagome unit cell
# Start by defining all the edges
graph = rx.PyGraph(multigraph=False)
graph.add_nodes_from(range(num_sites))
edge_list = [
    (0, 1, t),
    (1, 2, t),
    (2, 3, t),
    (3, 4, t),
    (4, 5, t),
    (5, 0, t),
    (0, 6, t),
    (1, 6, t),
    (1, 7, t),
    (2, 7, t),
    (2, 8, t),
    (3, 8, t),
    (3, 9, t),
    (4, 9, t),
    (4, 10, t),
    (5, 10, t),
    (5, 11, t),
    (0, 11, t),
]
singles_list = [
    #(0, 1, t),
    (1, 2, t),#
    #(2, 3, t),
    #(3, 4, t),
    #(4, 5, t), 
    (5, 0, t),#
    #(0, 6, t),
    #(1, 6, t),
    #(1, 7, t), 
    #(2, 7, t),
    #(2, 8, t),
    #(3, 8, t),
    (3, 9, t),#
    #(4, 9, t),
    (4, 10, t),#
    #(5, 10, t),
    #(5, 11, t),
    #(0, 11, t),
]

timereversal_list = [
    (0, 1, t),
    (1, 2, t),
    (2, 3, t),
    (3, 4, t),
    (4, 5, t),
    (5, 0, t),
    (6, 0, t), #reversed
    (1, 6, t),
    (7, 1, t), #reversed
    (2, 7, t),
    (8, 2, t), #reversed
    (3, 8, t),
    (9, 3, t), #reversed
    (4, 9, t),
    (10,4, t), #reversed
    (5, 10, t),
    (11, 5, t),#reversed
    (0, 11, t),
]
ring = [5,4,3,2,1,0]
tip = [11,10,9,8,7,6]
right = [5,3,1]
left = [4,2,0]


original_edge_list = edge_list
# Generate graph from the list of edges
graph.add_edges_from(edge_list)

# Make a Lattice from graph
kagome_unit_cell = Lattice(graph)

# Draw Lattice
kagome_unit_cell.draw(style={'with_labels':True,'font_color':'white','node_color':'purple'})
# plt.savefig('kagome_unit_cell.png')
plt.show()

# %% [markdown]
# Now that we have the lattice geometry, we can place each term in the Hamiltonian on its corresponding edge. This is done by using the custom `HeisenbergModel` found in the heisenberg_model.py file. This model is based on Qiskit Nature's [`IsingModel` class](https://qiskit.org/documentation/nature/stubs/qiskit_nature.second_q.hamiltonians.IsingModel.html) . It places $XX + YY + ZZ$ on each edge of the lattice (per the Hamiltonian's definition).
#
# We will also need to specify how the spin-1/2 particles map to qubits. Using Qiskit nature's `LogarithmicMapper`, we can map each spin-1/2 site to a single qubit. For more information on Qiskit nature's spin mappings see [here](https://qiskit.org/documentation/nature/stubs/qiskit_nature.second_q.mappers.SpinMapper.html#spinmapper).

# %%
from qiskit_nature.mappers.second_quantization import LogarithmicMapper

# %%
# Build Hamiltonian from graph edges
heis = HeisenbergModel.uniform_parameters(
    lattice=kagome_unit_cell,
    uniform_interaction=1.0,  # same spin-spin interaction weight as used in graph
    uniform_onsite_potential=0.0,  # No singe site external field
)

# The Lattice needs an explicit mapping to the qubit states.
# We map 1 qubit for 1 spin-1/2 particle using the LogarithmicMapper
log_mapper = LogarithmicMapper()
# Multiply by factor of 4 to account for (1/2)^2 terms from spin operators in the HeisenbergModel
ham = 4 * log_mapper.map(heis.second_q_ops().simplify())
# Print Hamiltonian to check it's what we expect.
# There are 18 edges and 3 terms per edge (XX, YY, and ZZ),
# so there should be 54 equally weighted terms.
ham
# Out:
# PauliSumOp(SparsePauliOp(['ZIIIIIZIIIII', 'IZIIIIZIIIII', 'IZIIIIIZIIII', 'IIZIIIIZIIII', 'IIIIIIZZIIII', 'IIZIIIIIZIII', 'IIIZIIIIZIII', 'IIIIIIIZZIII', 'IIIZIIIIIZII', 'IIIIZIIIIZII', 'IIIIIIIIZZII', 'IIIIZIIIIIZI', 'IIIIIZIIIIZI', 'IIIIIIIIIZZI', 'ZIIIIIIIIIIZ', 'IIIIIZIIIIIZ', 'IIIIIIZIIIIZ', 'IIIIIIIIIIZZ', 'YIIIIIYIIIII', 'IYIIIIYIIIII', 'IYIIIIIYIIII', 'IIYIIIIYIIII', 'IIIIIIYYIIII', 'IIYIIIIIYIII', 'IIIYIIIIYIII', 'IIIIIIIYYIII', 'IIIYIIIIIYII', 'IIIIYIIIIYII', 'IIIIIIIIYYII', 'IIIIYIIIIIYI', 'IIIIIYIIIIYI', 'IIIIIIIIIYYI', 'YIIIIIIIIIIY', 'IIIIIYIIIIIY', 'IIIIIIYIIIIY', 'IIIIIIIIIIYY', 'XIIIIIXIIIII', 'IXIIIIXIIIII', 'IXIIIIIXIIII', 'IIXIIIIXIIII', 'IIIIIIXXIIII', 'IIXIIIIIXIII', 'IIIXIIIIXIII', 'IIIIIIIXXIII', 'IIIXIIIIIXII', 'IIIIXIIIIXII', 'IIIIIIIIXXII', 'IIIIXIIIIIXI', 'IIIIIXIIIIXI', 'IIIIIIIIIXXI', 'XIIIIIIIIIIX', 'IIIIIXIIIIIX', 'IIIIIIXIIIIX', 'IIIIIIIIIIXX'],
#               coeffs=[1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j,
#  1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j,
#  1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j,
#  1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j,
#  1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j,
#  1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j]), coeff=1)

# %% [markdown]
# ### Compute ground state energy
# With the Hamiltonian in hand, we can now calculate the expected ground state and its energy. Qiskit offers different methods to do this. The method [here](https://qiskit.org/documentation/apidoc/algorithms.html#minimum-eigensolvers) computes the ground state energy. This [method](https://qiskit.org/documentation/apidoc/algorithms.html#eigensolvers) computes the ground state ($k=0$) and potentially higher energy states if the users wishes ($k>0$).
#
# Below is an example calculation of finding the lowest 3 energies ($k=3$) of the system using the second method. Remember that for this year's Prize, you will only need to use VQE to find the ground state energy and not any excited state energies.

# %%
from qiskit.algorithms import NumPyEigensolver

# find the first three (k=3) eigenvalues
exact_solver = NumPyEigensolver(k=3)
exact_result = exact_solver.compute_eigenvalues(ham)
print(exact_result.eigenvalues)

# Save ground state energy for later
gs_energy = np.round(exact_result.eigenvalues[0], 4)
# Out:
# [-18.         -18.         -16.96132284]

# %% [markdown]
# You'll note that -18 is found twice. This means there are actually two ground states for this system. The -16.96 energy is the first excited state, which is not part of this year's challenge. **For this year's Prize, we will only be judging based off the measured ground state energy. This means it does not matter which of the two ground states, or combination of them, your VQE implementation finds.**

# %% [markdown]
# ## 2-1 VQE with local runtime primitives
#
# To compute the ground state energy using VQE, we first pick an appropriate device. This year's Prize will use ibmq_guadalupe which has 16 qubits. This is 4 extra qubits than the Hamiltonian, so we will need to "inflate" the Hamiltonian with identity operators so we can measure 12 qubit Hamiltonian's energy expectation value on a 16 qubit device.
# After inflating the Hamiltonian, the anstaz and classical optimizer components are built up. Finally, a class is defined to bring everything together for the VQE algorithm, and it's executed on a local simulator.
#
# The code below is largely based off of this example [tutorial](https://github.com/mberna/qce22-qiskit-runtime-tutorial/blob/main/docs/tutorials/Building%20algorithms%20with%20Qiskit%20Runtime.ipynb) of using qiskit runtime primitives from IEEE week. Feel free to read through to learn more about qiskit runtime and VQE.

# %% [markdown]
# ## 2-2 Qiskit runtime
#
# [Qiskit runtime](https://github.com/Qiskit/qiskit-ibm-runtime) is a paradigm which brings classical and quantum computing resources closer together--speeding up quantum algorithms especially variational ones. We will be using runtime because of its [speed boost](https://research.ibm.com/blog/120x-quantum-speedup) relative to the traditional way quantum circuits are executed using qiskit. In this notebook, we'll demonstrate an example VQE executed with qiskit runtime, but we encourage you to get a deeper understanding of the tool by checking out an overview of qiskit runtime and some tutorials on the [qiskit docs section on runtime](https://qiskit.org/documentation/partners/qiskit_ibm_runtime/) as well as the IBM [research blog](https://research.ibm.com/blog/qiskit-runtime-capabilities-integration).

# %%
from qiskit import QuantumCircuit, transpile
from qiskit.circuit import Parameter

from qiskit import IBMQ

# %%
# Doc for loading IBMQ account https://quantum-computing.ibm.com/lab/docs/iql/manage/account/ibmq#the-account
# IBMQ.save_account(TOKEN)
IBMQ.load_account() # Load account from disk
provider = IBMQ.get_provider(hub='ibm-q-community', group='ibmquantumawards', project='open-science-22')

# Real backend; needed for transpilation later on
guadalupe = provider.get_backend("ibmq_guadalupe")

# Get fake backend if you like
# from qiskit.providers.fake_provider import FakeGuadalupe

# Noisy simulator backend
# noisy_sim = FakeGuadalupe()
# Out:
# ibmqfactory.load_account:WARNING:2023-02-20 13:21:38,691: Credentials are already in use. The existing account in the session will be replaced.

# %% [markdown]
# As mentioned at the beginning of this section, the system Hamiltonian is defined over 12 qubits, but ibmq_guadalupe has 16 qubits. To execute VQE on ibmq_guadalupe, we will "inflate" the Hamilontian from 12 qubits to 16 qubits to match ibmq_guadalupe, but those extra 4 qubits will not participate in the energy expectation value. Here, we've chosen the 4 qubits that won't participate to be 0, 6, 9, 15. You may pick different qubits.

# %%
# Kagome unit cell
num_qubits = 16
# Edge weight
t = 1.0

# Generate graph of kagome unit cell
# Start by defining all the edges
graph_16 = rx.PyGraph(multigraph=False)
graph_16.add_nodes_from(range(num_qubits))
edge_list = [
    (1, 2, t),
    (2, 3, t),
    (3, 5, t),
    (5, 8, t),
    (8, 11, t),
    (11, 14, t),
    (14, 13, t),
    (13, 12, t),
    (12, 10, t),
    (10, 7, t),
    (7, 4, t),
    (4, 1, t),
    (4, 2, t),
    (2, 5, t),
    (5, 11, t),
    (11, 13, t),
    (13, 10, t),
    (10, 4, t),
]

# Generate graph from the list of edges
graph_16.add_edges_from(edge_list)

# Make a Lattice from graph
kagome_unit_cell_16 = Lattice(graph_16)

# Draw Lattice and include labels to check we exclude the right spins
# Specify node locations for better visualizations
kagome_pos = {0:[1,-1], 6:[1.5,-1], 9:[2,-1], 15:[2.5,-1], 
              1:[0,-0.8], 2:[-0.6,1], 4:[0.6,1], 10:[1.2,3], 
              13:[0.6,5], 11:[-0.6,5], 5:[-1.2,3], 3:[-1.8,0.9], 
              8:[-1.8,5.1], 14:[0,6.8], 7:[1.8,0.9], 12:[1.8,5.1]}
kagome_unit_cell_16.draw(style={'with_labels':True, 'font_color':'white', 'node_color':'purple', 'pos':kagome_pos})
plt.show()

# %%
# Build Hamiltonian from graph edges
heis_16 = HeisenbergModel.uniform_parameters(
    lattice=kagome_unit_cell_16,
    uniform_interaction=t,
    uniform_onsite_potential=0.0,  # No singe site external field
)

# Map from SpinOp to qubits just as before.
log_mapper = LogarithmicMapper()
ham_16 = 4 * log_mapper.map(heis_16.second_q_ops().simplify())
# Print Hamiltonian to check it's what we expect:
# 18 ZZ, 18 YY, and 18 XX terms over 16 qubits instead of over 12 qubits
ham_16
# Out:
# PauliSumOp(SparsePauliOp(['IZZIIIIIIIIIIIII', 'IIZZIIIIIIIIIIII', 'IZIIZIIIIIIIIIII', 'IIZIZIIIIIIIIIII', 'IIZIIZIIIIIIIIII', 'IIIZIZIIIIIIIIII', 'IIIIZIIZIIIIIIII', 'IIIIIZIIZIIIIIII', 'IIIIZIIIIIZIIIII', 'IIIIIIIZIIZIIIII', 'IIIIIZIIIIIZIIII', 'IIIIIIIIZIIZIIII', 'IIIIIIIIIIZIZIII', 'IIIIIIIIIIZIIZII', 'IIIIIIIIIIIZIZII', 'IIIIIIIIIIIIZZII', 'IIIIIIIIIIIZIIZI', 'IIIIIIIIIIIIIZZI', 'IYYIIIIIIIIIIIII', 'IIYYIIIIIIIIIIII', 'IYIIYIIIIIIIIIII', 'IIYIYIIIIIIIIIII', 'IIYIIYIIIIIIIIII', 'IIIYIYIIIIIIIIII', 'IIIIYIIYIIIIIIII', 'IIIIIYIIYIIIIIII', 'IIIIYIIIIIYIIIII', 'IIIIIIIYIIYIIIII', 'IIIIIYIIIIIYIIII', 'IIIIIIIIYIIYIIII', 'IIIIIIIIIIYIYIII', 'IIIIIIIIIIYIIYII', 'IIIIIIIIIIIYIYII', 'IIIIIIIIIIIIYYII', 'IIIIIIIIIIIYIIYI', 'IIIIIIIIIIIIIYYI', 'IXXIIIIIIIIIIIII', 'IIXXIIIIIIIIIIII', 'IXIIXIIIIIIIIIII', 'IIXIXIIIIIIIIIII', 'IIXIIXIIIIIIIIII', 'IIIXIXIIIIIIIIII', 'IIIIXIIXIIIIIIII', 'IIIIIXIIXIIIIIII', 'IIIIXIIIIIXIIIII', 'IIIIIIIXIIXIIIII', 'IIIIIXIIIIIXIIII', 'IIIIIIIIXIIXIIII', 'IIIIIIIIIIXIXIII', 'IIIIIIIIIIXIIXII', 'IIIIIIIIIIIXIXII', 'IIIIIIIIIIIIXXII', 'IIIIIIIIIIIXIIXI', 'IIIIIIIIIIIIIXXI'],
#               coeffs=[1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j,
#  1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j,
#  1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j,
#  1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j,
#  1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j,
#  1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j]), coeff=1)

# %% [markdown]
# ## 2-3 Define an ansatz
# Crafting the ansatz is critical to VQE. You may use a prebuilt ansatz from the [qiskit circuit library](https://qiskit.org/documentation/apidoc/circuit_library.html#n-local-circuits). You may also make your own custom ansatz. Keep in mind that a custom ansatz should have no measurement gates at the end and the circuit parameters are defined by using `Parameter()` [objects](https://qiskit.org/documentation/stubs/qiskit.circuit.Parameter.html). We've demonstrated both options below. The ansatz can be defined over 12 qubits without needed to inflate it to 16 qubits at this point. The transpiler will take care of that later on.
#
# Here's an example using `EfficientSU2()` to generate an ansatz

# %%
from qiskit.circuit.library import EfficientSU2, RealAmplitudes

# %% [raw]
# # BEST -15.1542764816 SPSA(maxiter=175)
# ansatz_custom = RealAmplitudes(num_qubits = 12, entanglement = "linear", reps = 3, skip_final_rotation_layer = True)
# ansatz_custom.decompose().draw()

# %% [raw]
# # BEST -10.4888401104 SPSA(maxiter=175)
# ansatz_custom = QuantumCircuit(12)
# # build initial state
# ansatz_custom.h(range(0, 12, 2))
# ansatz_custom.cx(range(0, 11, 2), range(1, 12, 2))
# # First layer
# j = 0
# for i in range(12):
#     ansatz_custom.u(Parameter('θ_' + str(j)), -3 * np.pi/4, i,i)
#     if j<11:
#         ansatz_custom.cx(i+1,i)
#     #ansatz_custom.u(Parameter('θ_' + str(j)), np.pi/4, i, i)
#     #ansatz_custom.u(Parameter('θ_' + str(j)), 3 * np.pi/4, i, i)
#     j += 1
# ansatz_custom.cx(range(0, 11), range(1, 12))
#
# ansatz_custom.draw(fold=250)

# %% [raw]
# #BEST -15.983941061602948 SPSA(maxiter=575)
# ansatz_custom = QuantumCircuit(12)
# # build initial state
# ansatz_custom.h(range(0, 12, 2))
# ansatz_custom.cx(range(0, 11, 2), range(1, 12, 2))
# # First layer
# j = 0
# for i in range(12):
#     ansatz_custom.u(Parameter('θ_' + str(j)), Parameter('t_' + str(j)) * -3 * np.pi/4, Parameter('l_' + str(j)),i)
#     if j<11:
#         ansatz_custom.cx(i+1,i)
#     #ansatz_custom.u(Parameter('θ_' + str(j)), np.pi/4, i, i)
#     #ansatz_custom.u(Parameter('θ_' + str(j)), 3 * np.pi/4, i, i)
#     j += 1
# ansatz_custom.cx(range(0, 11), range(1, 12))
#
# ansatz_custom.draw(fold=250)

# %%
#BEST -16.123403234427226 SPSA(maxiter=575)
ansatz_custom = QuantumCircuit(12)
# build initial state
# First layer
j = 0
reps = 2
for rep in range(reps):
    ansatz_custom.h(range(0, 12, 2))
    ansatz_custom.cx(range(0, 11, 2), range(1, 12, 2))
    for i in range(12):
        if i in ring:
            if i in right:
                position = np.pi #3
                lam = 1
            else:    
                position = -np.pi #-3
                lam = 1
        elif i in tip:
            position = 1 #1 np.pi not better 
            lam = Parameter('l_' + str(j))
        ansatz_custom.rz(Parameter('θ_' + str(j)), i)
        j += 1
        ansatz_custom.ry(Parameter('θ_' + str(j)) * position * np.pi/4, i)
        j += 1
        #ansatz_custom.u(Parameter('θ_' + str(j)), Parameter('t_' + str(j)) * position * np.pi/4, lam, i)
        if j<11:
            ansatz_custom.cx(i+1,i)
        #ansatz_custom.u(Parameter('θ_' + str(j)), np.pi/4, i, i)
        #ansatz_custom.u(Parameter('θ_' + str(j)), 3 * np.pi/4, i, i)
        j += 1
    ansatz_custom.cx(range(0, 11), range(1, 12))

ansatz_custom.draw(fold=250)

# %% [raw]
# # Build a custom ansatz from scratch
# ansatz_custom = QuantumCircuit(12)
# # build initial state
# ansatz_custom.h(range(0, 12, 2))
# ansatz_custom.cx(range(0, 11, 2), range(1, 12, 2))
# # First layer
# j = 0
# for edge in original_edge_list:
#     if j<11:
#         ansatz_custom.u(Parameter('θ_' + str(j)), -3 * np.pi/4, 1-j%2,j)
#         ansatz_custom.cx(edge[1], edge[0])
#     #ansatz_custom.u(Parameter('θ_' + str(j)), np.pi/4, i, i)
#     #ansatz_custom.u(Parameter('θ_' + str(j)), 3 * np.pi/4, i, i)
#     j += 1
# ansatz_custom.cx(range(0, 11), range(1, 12))
#
# ansatz_custom.draw(fold=250)

# %% [raw]
# # Construct ansatz from qiskit circuit library functions
# # See docs for full details
# ansatz = EfficientSU2(12, entanglement='linear', reps=3, skip_final_rotation_layer=True).decompose()
# ansatz.draw(fold=300)

# %% [markdown]
# Here's an example of building a custom ansatz. We'll continue using this one for the rest of the notebook.

# %% [raw]
# # Build a custom ansatz from scratch
# ansatz_custom = QuantumCircuit(12)
# # build initial state
# ansatz_custom.h(range(0, 12, 2))
# ansatz_custom.cx(range(0, 11, 2), range(1, 12, 2))
# # First layer
# j = 0
# for i in range(12):
#     ansatz_custom.rz(Parameter('θ_' + str(j)), i)
#     j += 1
#     ansatz_custom.ry(Parameter('θ_' + str(j)), i)
#     j += 1
# ansatz_custom.cx(range(0, 11), range(1, 12))
#
# ansatz_custom.draw(fold=250)

# %% [markdown]
# ### Match qubit layout
# The ansatz is currently defined over 12 qubits, but it will be executed on guadalupe which has 16 qubits. To make the ansatz compatible with guadalupe and the inflated Hamiltonian, we can specify the qubit layout on the real device using the transpiler (shown below). We exclude the four qubits with fewest neighbors.

# %%
# Force anstaz to be applied to qubits in the heavy hex.
# Avoid the outer qubits 0, 6, 9, and 15 which we accounted for in the lattice definition.
q_layout = [1, 2, 3, 5, 8, 11, 14, 13, 12, 10, 7, 4]
ansatz_opt = transpile(ansatz_custom, backend=guadalupe, initial_layout=q_layout)

print('number and type of gates in the cirucit:', ansatz_opt.count_ops())
print('number of parameters in the circuit:', ansatz_opt.num_parameters)
#ansatz_opt.draw(fold=300)
# Out:
# number and type of gates in the cirucit: OrderedDict([('rz', 96), ('sx', 60), ('cx', 37)])
# number of parameters in the circuit: 48

# %% [markdown]
# ## 2-4 Choose a classical optimizer
# Select a [classical optimizer](https://qiskit.org/documentation/stubs/qiskit.algorithms.optimizers.html#local-optimizers). The classical optimizer will encounter errored and stochastic results from the quantum computer due to gate errors, measurement errors, and other noise sources as well as finite sampling affects [8]. Choose a classical optimizer that pairs well with your approach to VQE. Along with choosing a classical optimizer, picking an initial set of parameters plays a significant role in VQE. In this example, a random set of values is picked (shown in the `CustomVQE` class section 2-5).
#
# \[8\] "Using models to improve optimizers for variational quantum algorithms" K. Sung, et al. [arXiv:2005.11011v2](https://arxiv.org/abs/2005.11011v2) [quant-ph] (2020)

# %%
from qiskit.algorithms.optimizers import SPSA, SLSQP, L_BFGS_B, GradientDescent

optimizer = SPSA(maxiter=75)

# %% [markdown]
# ## 2-5 Define custom VQE program
# The VQE calculation can be efficiently orchestrated between the quantum and classical computer using qiskit's [primitives](https://qiskit.org/documentation/apidoc/primitives.html). Below is a simple example of using the [Estimator primitive](https://qiskit.org/documentation/apidoc/primitives.html#overview-of-estimator) with your computer as a local simulator of a quantum computer. It's convenient to bring the components of VQE together into a custom class which we've called `CustomVQE`.
#
# If you want more control over the measurement results and how the expectation values are computed, use the [Sampler primitive](https://qiskit.org/documentation/apidoc/primitives.html#overview-of-sampler) which will output the probabilities (or quasi-probabilities) of every measured state instead of expectation values.

# %%
from qiskit.algorithms import MinimumEigensolver, VQEResult

# Define a custome VQE class to orchestra the ansatz, classical optimizers, 
# initial point, callback, and final result
class CustomVQE(MinimumEigensolver):
    
    def __init__(self, estimator, circuit, optimizer, callback=None, init_data=[]):
        self._estimator = estimator
        self._circuit = circuit
        self._optimizer = optimizer
        self._callback = callback
        self._init_data = init_data
        
    def compute_minimum_eigenvalue(self, operators, aux_operators=None):
                
        # Define objective function to classically minimize over
        def objective(x):
            # Execute job with estimator primitive
            job = self._estimator.run([self._circuit], [operators], [x])
            print("EstimatorJob:", job.job_id())
            # Get results from jobs
            est_result = job.result()
            # Get the measured energy value
            value = est_result.values[0]
            print("Job Value:", job.job_id(), value)
            # Save result information using callback function
            if self._callback is not None:
                self._callback(value)
            return value
            
        # Select an initial point for the ansatzs' parameters
        if len(self._init_data) > 0:
            x0 = init_data
        else:
            x0 = np.pi/4 * np.random.rand(self._circuit.num_parameters)
        
        # Run optimization
        res = self._optimizer.minimize(objective, x0=x0)
        
        # Populate VQE result
        result = VQEResult()
        result.cost_function_evals = res.nfev
        result.eigenvalue = res.fun
        result.optimal_parameters = res.x
        return result

# %% [markdown]
# ### Callback
# It's important to know what's going on between the classical and quantum computer during the optimization. What parameter values is the classical optimizer picking? How does the convergence to the ground state energy behave?
#
# Defining a callback function gives us a chance to peek in. A simple callback method is defined below. See [this tutorial](https://qiskit.org/documentation/tutorials/algorithms/02_vqe_convergence.html) for more information and be sure to read the classical [optimizers' docs](https://qiskit.org/documentation/stubs/qiskit.algorithms.optimizers.html) for what specific values can be extracted during optimization. For example [SPSA](https://qiskit.org/documentation/stubs/qiskit.algorithms.optimizers.SPSA.html#qiskit.algorithms.optimizers.SPSA) returns: (nfev, parameters, value, stepsize, accepted).

# %%
# Define a simple callback function
intermediate_info = []
def callback(value):
        intermediate_info.append(value)

# %% [markdown]
# ## 2-6 Execute simulated VQE
# The VQE is built! Time to test it out on a simulator. This may take a few seconds.

# %%
from qiskit.primitives import Estimator
init_data = np.array([ 5.14683864,  0.00821233, -2.86578078,  2.64538161, -3.74786115,
       -0.59346493,  0.84044682,  1.35385538,  1.46952694, -0.64877215,
        0.01577877, -0.84281735,  1.28355626, -1.74748509, -3.07817285,
       -8.07728096, -3.65782441, -1.92480235,  0.93414431,  0.9090003 ,
        3.12258109, -3.90935648,  2.88916305, -0.4661917 ,  3.13347152,
        3.1334792 , -3.16264778,  0.04237658,  3.18247102, -2.06333433])

# %%
# Define instance of qiskit-terra's Estimator primitive
estimator = Estimator([ansatz_opt], [ham_16])

# Setup VQE algorithm
custom_vqe = CustomVQE(estimator, ansatz_opt, optimizer, callback=callback)

# Run the custom VQE function and monitor execution time
start = time()
result = custom_vqe.compute_minimum_eigenvalue(ham_16)
end = time()

print(result)
print(f'execution time (s): {end - start:.2f}')
# Out:
# EstimatorJob: b02c4516-c3ae-4119-a149-4a4ddcf120f4
# Job Value: b02c4516-c3ae-4119-a149-4a4ddcf120f4 5.204812177707835
# EstimatorJob: d719f3bd-986e-4d10-97c9-a20e6980e40b
# Job Value: d719f3bd-986e-4d10-97c9-a20e6980e40b 2.1082032051810797
# EstimatorJob: 9f67c138-2ba4-434f-ad62-0c7a6239516c
# Job Value: 9f67c138-2ba4-434f-ad62-0c7a6239516c 3.136139243871377
# EstimatorJob: 7e99a936-91cf-4b5e-8d8c-1473ab770dc6
# Job Value: 7e99a936-91cf-4b5e-8d8c-1473ab770dc6 3.904393440044893
# EstimatorJob: 9a58e41c-e3c1-4862-999e-4809db71d02d
# Job Value: 9a58e41c-e3c1-4862-999e-4809db71d02d 4.609555361841689
# EstimatorJob: 3ad1cde2-94ba-41c9-8982-420354380e18
# Job Value: 3ad1cde2-94ba-41c9-8982-420354380e18 2.363389354030867
# EstimatorJob: 76fd92ba-9f22-4ca2-bd24-867a5a795214
# Job Value: 76fd92ba-9f22-4ca2-bd24-867a5a795214 1.7052561110311384
# EstimatorJob: 0df25b7f-59d3-413e-97a8-df29c4898467
# Job Value: 0df25b7f-59d3-413e-97a8-df29c4898467 5.066511820399822
# EstimatorJob: fe6ae070-db13-43d8-a3ef-2b14683e9db2
# Job Value: fe6ae070-db13-43d8-a3ef-2b14683e9db2 3.5529009256987942
# EstimatorJob: 48bccd62-0563-4854-ac36-ef7867b3e0e9
# Job Value: 48bccd62-0563-4854-ac36-ef7867b3e0e9 2.3142808648489877
# EstimatorJob: 6d3601e8-3446-4428-ba5c-202b1552ef60
# Job Value: 6d3601e8-3446-4428-ba5c-202b1552ef60 1.827822027673226
# EstimatorJob: b10c1e85-45e0-416d-8f1f-3f6f80364b0d
# Job Value: b10c1e85-45e0-416d-8f1f-3f6f80364b0d 2.8603845482356913
# EstimatorJob: 37079cca-494f-4c42-a289-e54b02cccecf
# Job Value: 37079cca-494f-4c42-a289-e54b02cccecf 2.423007395054179
# EstimatorJob: 3c1f14ba-40ed-4079-af9e-cf8c4c722f5f
# Job Value: 3c1f14ba-40ed-4079-af9e-cf8c4c722f5f 3.1026267360620836
# EstimatorJob: 3270accc-d428-439e-9c5e-e4c8d7181f71
# Job Value: 3270accc-d428-439e-9c5e-e4c8d7181f71 3.978115247686233
# EstimatorJob: e56befa4-14e8-4f2d-b08a-3086e73e6d5c
# Job Value: e56befa4-14e8-4f2d-b08a-3086e73e6d5c 0.5642886431550327
# EstimatorJob: 8db3ba05-5f53-4e22-a86f-7e53656940d3
# Job Value: 8db3ba05-5f53-4e22-a86f-7e53656940d3 4.329539675548828
# EstimatorJob: 6823cd03-7ce7-41e8-87e7-e7f1bdf8ccd5
# Job Value: 6823cd03-7ce7-41e8-87e7-e7f1bdf8ccd5 2.179940947794582
# EstimatorJob: 83bea72b-c8cf-4eed-9a88-386dce88beff
# Job Value: 83bea72b-c8cf-4eed-9a88-386dce88beff 4.691533373857938
# EstimatorJob: f4dd5790-1d03-445a-a5b2-850f2482dbe5
# Job Value: f4dd5790-1d03-445a-a5b2-850f2482dbe5 3.4072677386328167
# EstimatorJob: 9824cbd5-49af-4899-a8d6-8525a197824d
# Job Value: 9824cbd5-49af-4899-a8d6-8525a197824d 1.281130897651906
# EstimatorJob: 86e81c81-41d3-43f2-ba1e-29d8341d0d82
# Job Value: 86e81c81-41d3-43f2-ba1e-29d8341d0d82 2.8318073236081798
# EstimatorJob: 211e05d4-5911-4137-bf56-2e821d42a664
# Job Value: 211e05d4-5911-4137-bf56-2e821d42a664 3.1683438031529567
# EstimatorJob: eb97f420-3dd8-448f-be41-bc2a9224f2ce
# Job Value: eb97f420-3dd8-448f-be41-bc2a9224f2ce 2.8610535476374546
# EstimatorJob: 6415bbee-2390-4370-ad8a-09fcba91618b
# Job Value: 6415bbee-2390-4370-ad8a-09fcba91618b 3.776115399519686
# EstimatorJob: a52fe37e-866e-42f7-9ae8-a0687915dc36
# Job Value: a52fe37e-866e-42f7-9ae8-a0687915dc36 1.7396303447584167
# EstimatorJob: bd42bdeb-4841-4f19-9d69-e8b86c398a7f
# Job Value: bd42bdeb-4841-4f19-9d69-e8b86c398a7f 3.987338244265022
# EstimatorJob: d34f8bde-c570-4cb5-ba21-ac63fdc2a16b
# Job Value: d34f8bde-c570-4cb5-ba21-ac63fdc2a16b 4.409180100574407
# EstimatorJob: 025eca1d-08b4-491e-b7a1-969dfd08dd2c
# Job Value: 025eca1d-08b4-491e-b7a1-969dfd08dd2c 2.5978732205092685
# EstimatorJob: 87806197-25be-4782-9641-611fcaa7f605
# Job Value: 87806197-25be-4782-9641-611fcaa7f605 3.5301451899935286
# EstimatorJob: 91af9091-ac95-43bd-9019-50d2aff93047
# Job Value: 91af9091-ac95-43bd-9019-50d2aff93047 4.857234488173773
# EstimatorJob: e4c0fcc5-91f3-4c4a-a053-58fda2dc6041
# Job Value: e4c0fcc5-91f3-4c4a-a053-58fda2dc6041 3.0359882789822383
# EstimatorJob: 492ff3e6-dc7e-4497-b338-973c1d7afd0c
# Job Value: 492ff3e6-dc7e-4497-b338-973c1d7afd0c 1.8775343691135178
# EstimatorJob: ddde8fed-ace8-4c04-ab3a-1b859edf654b
# Job Value: ddde8fed-ace8-4c04-ab3a-1b859edf654b 5.6101802151983415
# EstimatorJob: 1487fd09-4d21-484c-a6a8-de3be6753f4c
# Job Value: 1487fd09-4d21-484c-a6a8-de3be6753f4c 3.1462173330605085
# EstimatorJob: 93a2336e-4ac2-4e33-959c-0bbdfbd2ab67
# Job Value: 93a2336e-4ac2-4e33-959c-0bbdfbd2ab67 3.7853902867739952
# EstimatorJob: eda2184a-2979-4a17-acdf-16b418c4618d
# Job Value: eda2184a-2979-4a17-acdf-16b418c4618d 2.1095258711461033
# EstimatorJob: 0365c319-85e9-47f6-89dc-63b3fea9a5a3
# Job Value: 0365c319-85e9-47f6-89dc-63b3fea9a5a3 5.417232599551356
# EstimatorJob: 228ce382-990a-4edb-b852-d3994ea215e2
# Job Value: 228ce382-990a-4edb-b852-d3994ea215e2 4.055459495483269
# EstimatorJob: 1c3e8fdb-5e87-487b-9a78-7dcc3d960e69
# Job Value: 1c3e8fdb-5e87-487b-9a78-7dcc3d960e69 3.9592386977242104
# EstimatorJob: 36395557-5d2b-48cd-b244-d8ea73a93fc0
# Job Value: 36395557-5d2b-48cd-b244-d8ea73a93fc0 3.024726116495194
# EstimatorJob: edd5bb80-ac6a-4cc9-8dda-e14d060aff6a
# Job Value: edd5bb80-ac6a-4cc9-8dda-e14d060aff6a 2.642901695918149
# EstimatorJob: 2f994705-e85a-40a9-af67-239f4511436a
# Job Value: 2f994705-e85a-40a9-af67-239f4511436a 3.895173843867841
# EstimatorJob: 0550ce09-49a3-4df9-9a93-599043a5e03d
# Job Value: 0550ce09-49a3-4df9-9a93-599043a5e03d 2.0815393053105975
# EstimatorJob: b1cb45ff-0891-461a-8a29-3e9215008f12
# Job Value: b1cb45ff-0891-461a-8a29-3e9215008f12 3.3923826431778843
# EstimatorJob: dce91d14-f1d7-4e5c-a6f6-c9821125cc13
# Job Value: dce91d14-f1d7-4e5c-a6f6-c9821125cc13 1.137661527660262
# EstimatorJob: 2185f0ec-148b-48b2-a511-d4fd90d20005
# Job Value: 2185f0ec-148b-48b2-a511-d4fd90d20005 2.0794624284115013
# EstimatorJob: 37e5b113-eeb1-42e5-a8ee-1e17599a7f08
# Job Value: 37e5b113-eeb1-42e5-a8ee-1e17599a7f08 3.0192735395663455
# EstimatorJob: faddfdf2-c2b9-4887-baeb-abbbd593b7f6
# Job Value: faddfdf2-c2b9-4887-baeb-abbbd593b7f6 1.9055314502924978
# EstimatorJob: e202a213-c5f9-4c08-987b-4c75066c980a
# Job Value: e202a213-c5f9-4c08-987b-4c75066c980a 4.043808930670108
# EstimatorJob: 4aa73c66-fcc3-483c-8b89-b9962c444d39
# Job Value: 4aa73c66-fcc3-483c-8b89-b9962c444d39 1.5360772095908821
# EstimatorJob: 4b01cbd4-2817-4fa9-ac8a-ba201b969ad7
# Job Value: 4b01cbd4-2817-4fa9-ac8a-ba201b969ad7 2.831015462367869
# EstimatorJob: 3b75aa6a-3488-4246-a4da-bae0c10435b1
# Job Value: 3b75aa6a-3488-4246-a4da-bae0c10435b1 0.7819941647202204
# EstimatorJob: d9aa2259-e402-45b0-894f-c5651077fc16
# Job Value: d9aa2259-e402-45b0-894f-c5651077fc16 1.4717183765853517
# EstimatorJob: 87c42cbc-426b-4c71-b45d-fd6dc82df2df
# Job Value: 87c42cbc-426b-4c71-b45d-fd6dc82df2df 0.6578736576031146
# EstimatorJob: 1f026733-0003-4236-a6ed-27fb0f161cbb
# Job Value: 1f026733-0003-4236-a6ed-27fb0f161cbb 0.7689053020118017
# EstimatorJob: 35684d61-f8f5-4dfc-a8dd-3460b27e9778
# Job Value: 35684d61-f8f5-4dfc-a8dd-3460b27e9778 1.6511898118779567
# EstimatorJob: 722a1028-3de4-4afa-9437-05003c9fdc93
# Job Value: 722a1028-3de4-4afa-9437-05003c9fdc93 -0.6973086279285559
# EstimatorJob: df02b7d8-4a18-410b-8f0e-5b2fe992d65d
# Job Value: df02b7d8-4a18-410b-8f0e-5b2fe992d65d -2.2919509795563116
# EstimatorJob: 4aa49410-d10b-44a9-9c4b-9627a17e139e
# Job Value: 4aa49410-d10b-44a9-9c4b-9627a17e139e -1.446255381242274
# EstimatorJob: 720ba55c-c4e0-43c9-9545-d6e75f4f74be
# Job Value: 720ba55c-c4e0-43c9-9545-d6e75f4f74be -1.997477880071797
# EstimatorJob: 4c5cd246-218b-4415-bc4d-e3185b1b7af4
# Job Value: 4c5cd246-218b-4415-bc4d-e3185b1b7af4 -1.6726657520316544
# EstimatorJob: 3557a351-8e9a-488b-a137-1fceed2cdf49
# Job Value: 3557a351-8e9a-488b-a137-1fceed2cdf49 -2.7539614382408093
# EstimatorJob: be204a51-708d-4974-8798-e7082ca9f920
# Job Value: be204a51-708d-4974-8798-e7082ca9f920 -1.094587729573323
# EstimatorJob: c442694c-86ea-4b71-949e-d679f8715899
# Job Value: c442694c-86ea-4b71-949e-d679f8715899 -1.7926807509767773
# EstimatorJob: ea9edf34-80e6-48ca-9058-f40477be431c
# Job Value: ea9edf34-80e6-48ca-9058-f40477be431c -0.886641426191618
# EstimatorJob: a5c8efd6-24e2-4d5d-ae9a-5b9fa077a5c0
# Job Value: a5c8efd6-24e2-4d5d-ae9a-5b9fa077a5c0 -0.4612584230972281
# EstimatorJob: 68cb6eb9-e04f-456f-aca5-15c733ef8a2c
# Job Value: 68cb6eb9-e04f-456f-aca5-15c733ef8a2c -2.3564805620508698
# EstimatorJob: 8414f12f-7c36-467e-b713-0c2562747cda
# Job Value: 8414f12f-7c36-467e-b713-0c2562747cda -2.1437034092769243
# EstimatorJob: 4f3c11d5-afa3-490e-871e-6fd654a77a38
# Job Value: 4f3c11d5-afa3-490e-871e-6fd654a77a38 -2.1164626711846997
# EstimatorJob: 9f7edffe-5b7e-44bb-8a4d-5511e8116145
# Job Value: 9f7edffe-5b7e-44bb-8a4d-5511e8116145 -2.029670462362818
# EstimatorJob: dc3cefed-859b-49eb-bec4-f188e15502e2
# Job Value: dc3cefed-859b-49eb-bec4-f188e15502e2 -1.506598193988975
# EstimatorJob: 061d9ef5-9493-4b53-98f6-e901a8e280e4
# Job Value: 061d9ef5-9493-4b53-98f6-e901a8e280e4 -1.5432892104338287
# EstimatorJob: cc28f942-6295-4b3d-9c9f-0888e156b263
# Job Value: cc28f942-6295-4b3d-9c9f-0888e156b263 -1.4269521458599372
# EstimatorJob: 8bef1480-a247-492c-be83-0598618aaf67
# Job Value: 8bef1480-a247-492c-be83-0598618aaf67 -1.6196161688864612
# EstimatorJob: 3ad90bbc-86ec-4b35-b260-e564f6e9b35d
# Job Value: 3ad90bbc-86ec-4b35-b260-e564f6e9b35d -1.7075625166362867
# EstimatorJob: 66cbe9ee-6006-4bab-98cd-ecde5aa27829
# Job Value: 66cbe9ee-6006-4bab-98cd-ecde5aa27829 -0.7103064859734562
# EstimatorJob: 74e5a25e-bd60-480d-b299-4b6c0c50e031
# Job Value: 74e5a25e-bd60-480d-b299-4b6c0c50e031 -2.326180562989412
# EstimatorJob: 46a08a32-1022-4cdd-8b44-0d282985dbde
# Job Value: 46a08a32-1022-4cdd-8b44-0d282985dbde -2.7442542942259798
# EstimatorJob: e2e2fde5-ff0c-449e-9349-dab4eef9de7a
# Job Value: e2e2fde5-ff0c-449e-9349-dab4eef9de7a -2.087562117991739
# EstimatorJob: fbeaf1f0-5e9d-486a-9e44-f510daa921f9
# Job Value: fbeaf1f0-5e9d-486a-9e44-f510daa921f9 -2.486987801624875
# EstimatorJob: 75c7448e-1dad-4686-a094-0e4ba4e09e42
# Job Value: 75c7448e-1dad-4686-a094-0e4ba4e09e42 -1.4561073640465385
# EstimatorJob: e9c929da-9486-48fd-925a-153488c19b69
# Job Value: e9c929da-9486-48fd-925a-153488c19b69 -1.6321189402970147
# EstimatorJob: 0d123536-abaa-4dc6-a3e4-160cdc14f597
# Job Value: 0d123536-abaa-4dc6-a3e4-160cdc14f597 -2.1912184476398475
# EstimatorJob: cbdf4655-c959-4ca5-850e-5806f59be888
# Job Value: cbdf4655-c959-4ca5-850e-5806f59be888 -2.150179502347815
# EstimatorJob: 2a7be732-647e-41fb-b9e9-17fe4aa3bba9
# Job Value: 2a7be732-647e-41fb-b9e9-17fe4aa3bba9 -2.486134885053343
# EstimatorJob: d66e2f32-f3a8-4496-9f8e-c4e39d9a0c80
# Job Value: d66e2f32-f3a8-4496-9f8e-c4e39d9a0c80 -1.6989820189723523
# EstimatorJob: ae59ede6-1049-46ca-895e-47341ae77b8b
# Job Value: ae59ede6-1049-46ca-895e-47341ae77b8b -2.240008856426033
# EstimatorJob: 96bf9544-a1e4-4460-8261-84c4d9bf9043
# Job Value: 96bf9544-a1e4-4460-8261-84c4d9bf9043 -1.7448662480924484
# EstimatorJob: c42ca814-fcdd-4b03-8881-866c3980d0ce
# Job Value: c42ca814-fcdd-4b03-8881-866c3980d0ce -2.1237267693205304
# EstimatorJob: 3065ffe6-85e9-4bca-bfdc-47d9b200b48a
# Job Value: 3065ffe6-85e9-4bca-bfdc-47d9b200b48a -3.183078790741135
# EstimatorJob: fd8c7cab-46e3-4d77-b25a-863fdb64f7e2
# Job Value: fd8c7cab-46e3-4d77-b25a-863fdb64f7e2 -2.553054301084725
# EstimatorJob: 26703842-81c6-4269-975d-bd10ea4ac9c0
# Job Value: 26703842-81c6-4269-975d-bd10ea4ac9c0 -2.3702860156799868
# EstimatorJob: cfc44d08-ce22-4b3b-969b-5876dcec3611
# Job Value: cfc44d08-ce22-4b3b-969b-5876dcec3611 -3.4373053800810704
# EstimatorJob: 7b089e8f-a24f-479a-85b9-7a2d4be23cbe
# Job Value: 7b089e8f-a24f-479a-85b9-7a2d4be23cbe -3.5516042906534793
# EstimatorJob: d06fe02a-2cb1-4c2e-b5e9-7dafa57970c6
# Job Value: d06fe02a-2cb1-4c2e-b5e9-7dafa57970c6 -2.2864631505545705
# EstimatorJob: 372d719e-7e6a-4fb1-a572-cf5c030d5a0c
# Job Value: 372d719e-7e6a-4fb1-a572-cf5c030d5a0c -2.383876193865692
# EstimatorJob: 9c5bcde2-c755-438b-ad0f-83caddae4c06
# Job Value: 9c5bcde2-c755-438b-ad0f-83caddae4c06 -3.446922711912422
# EstimatorJob: 53594d29-2931-4bb9-be2f-935b34bb50f4
# Job Value: 53594d29-2931-4bb9-be2f-935b34bb50f4 -2.4125936559862065
# EstimatorJob: 2a9a0d69-3b54-4309-bbb0-a57ea0078f98
# Job Value: 2a9a0d69-3b54-4309-bbb0-a57ea0078f98 -2.749820649916941
# EstimatorJob: bade417c-4c95-4373-99e5-333246dfb47d
# Job Value: bade417c-4c95-4373-99e5-333246dfb47d -2.762669623282606
# EstimatorJob: 841444e9-8f5a-46d4-9f2f-af87690977ee
# Job Value: 841444e9-8f5a-46d4-9f2f-af87690977ee -2.168574652701361
# EstimatorJob: 92ec43f2-74a9-405e-9a3b-01204f376ee6
# Job Value: 92ec43f2-74a9-405e-9a3b-01204f376ee6 -3.493924428495625
# EstimatorJob: 1c48ec40-6425-4dfc-a90e-00d542f33103
# Job Value: 1c48ec40-6425-4dfc-a90e-00d542f33103 -2.0743075597978047
# EstimatorJob: 0581cee6-7956-4b1b-a92d-9686430279ec
# Job Value: 0581cee6-7956-4b1b-a92d-9686430279ec -1.697244881079534
# EstimatorJob: 5c3d9f0f-94d1-41c6-9de2-c5b5fa8d6860
# Job Value: 5c3d9f0f-94d1-41c6-9de2-c5b5fa8d6860 -3.9726075257436366
# EstimatorJob: 9a1e8e00-e876-464e-97bd-04298dd11adf
# Job Value: 9a1e8e00-e876-464e-97bd-04298dd11adf -3.0358592388886687
# EstimatorJob: ac9d22d6-6005-4232-a1f7-2dd659279727
# Job Value: ac9d22d6-6005-4232-a1f7-2dd659279727 -3.162820936311447
# EstimatorJob: eb75eff9-692a-44b0-ae09-bae7ea9d2663
# Job Value: eb75eff9-692a-44b0-ae09-bae7ea9d2663 -3.0976307766693956
# EstimatorJob: 446b7822-3cae-4d9b-b861-0c49a43ecf83
# Job Value: 446b7822-3cae-4d9b-b861-0c49a43ecf83 -3.395185786429763
# EstimatorJob: e0f08bbe-668e-46f4-bba4-c8056c4ce034
# Job Value: e0f08bbe-668e-46f4-bba4-c8056c4ce034 -2.5007493830211294
# EstimatorJob: 395c6178-ae95-401f-97a5-e1ca172a0a25
# Job Value: 395c6178-ae95-401f-97a5-e1ca172a0a25 -4.022010785723864
# EstimatorJob: 72e9c8ca-587e-492b-a6e2-48d2fec9e49d
# Job Value: 72e9c8ca-587e-492b-a6e2-48d2fec9e49d -3.9596989944894734
# EstimatorJob: ca46a9b0-50b8-435f-aa42-8d9aebf8f61b
# Job Value: ca46a9b0-50b8-435f-aa42-8d9aebf8f61b -2.5259996334013306
# EstimatorJob: 79488c53-60f9-45e0-9d0e-bda6e9a45ceb
# Job Value: 79488c53-60f9-45e0-9d0e-bda6e9a45ceb -3.9644517550892986
# EstimatorJob: 86443a5e-ffdf-4a4e-aa75-7ae24e4c0789
# Job Value: 86443a5e-ffdf-4a4e-aa75-7ae24e4c0789 -3.3229504208974414
# EstimatorJob: 559d908c-cc0e-45de-b221-e1b2d11fe2fe
# Job Value: 559d908c-cc0e-45de-b221-e1b2d11fe2fe -3.539392974001996
# EstimatorJob: 0a024e84-dc15-4f60-8acf-fbe49c7901a9
# Job Value: 0a024e84-dc15-4f60-8acf-fbe49c7901a9 -4.165348844841365
# EstimatorJob: 17f16796-980b-42d4-bf9b-1f075d587f6a
# Job Value: 17f16796-980b-42d4-bf9b-1f075d587f6a -3.585052990313101
# EstimatorJob: 11cb46db-306c-49b2-a81b-93fa40670ad5
# Job Value: 11cb46db-306c-49b2-a81b-93fa40670ad5 -4.341556158278461
# EstimatorJob: 43e50ce8-8096-43e1-b52a-ae5be14d234f
# Job Value: 43e50ce8-8096-43e1-b52a-ae5be14d234f -3.406981058930275
# EstimatorJob: d27b71e2-6492-481f-b915-9d8f0d19af11
# Job Value: d27b71e2-6492-481f-b915-9d8f0d19af11 -4.018533908337288
# EstimatorJob: 3f542d40-1f02-48a1-a738-7a87e7e2aea6
# Job Value: 3f542d40-1f02-48a1-a738-7a87e7e2aea6 -4.093799549377299
# EstimatorJob: 7595c8b3-a6cf-4e56-b11d-8f8ea8fb794b
# Job Value: 7595c8b3-a6cf-4e56-b11d-8f8ea8fb794b -3.5341966406057477
# EstimatorJob: e9c5321c-6dd7-4e4b-acaa-f97db0e068ab
# Job Value: e9c5321c-6dd7-4e4b-acaa-f97db0e068ab -4.283590536934854
# EstimatorJob: 90405bb5-52a3-45b8-b9b0-f90d8794f34e
# Job Value: 90405bb5-52a3-45b8-b9b0-f90d8794f34e -3.549852730518447
# EstimatorJob: fe28f4e3-7620-49a6-98b1-597b213bbd6f
# Job Value: fe28f4e3-7620-49a6-98b1-597b213bbd6f -3.7827248119952563
# EstimatorJob: 48d01cc6-e89c-4576-b297-dde8c3994c4c
# Job Value: 48d01cc6-e89c-4576-b297-dde8c3994c4c -4.3241500505600365
# EstimatorJob: c37c258d-47f1-4b84-b073-6a1219662704
# Job Value: c37c258d-47f1-4b84-b073-6a1219662704 -4.839766533349745
# EstimatorJob: 15b3ca61-9319-4554-9f8a-2afe44a6ef06
# Job Value: 15b3ca61-9319-4554-9f8a-2afe44a6ef06 -3.7065193072907667
# EstimatorJob: 21faf774-e3ab-4576-a0b9-a5debc7661ad
# Job Value: 21faf774-e3ab-4576-a0b9-a5debc7661ad -3.4960938497519334
# EstimatorJob: 24139898-0e41-496a-a515-5d82bebadb4c
# Job Value: 24139898-0e41-496a-a515-5d82bebadb4c -4.4829029527091535
# EstimatorJob: be545a9b-3c7c-4c99-bf31-5f28cb2a2177
# Job Value: be545a9b-3c7c-4c99-bf31-5f28cb2a2177 -3.8429878298362716
# EstimatorJob: 8eb4e2b0-664f-466c-817c-0ab6a0142960
# Job Value: 8eb4e2b0-664f-466c-817c-0ab6a0142960 -4.677045160611637
# EstimatorJob: 384b1eb1-b4bb-48bb-a10d-26034f2b885a
# Job Value: 384b1eb1-b4bb-48bb-a10d-26034f2b885a -4.657389596067779
# EstimatorJob: 8bed81fe-ff3d-4e60-bd3f-fc941611b6e7
# Job Value: 8bed81fe-ff3d-4e60-bd3f-fc941611b6e7 -4.012814444387814
# EstimatorJob: c6477d2a-b661-4cea-bb18-a3a518422ede
# Job Value: c6477d2a-b661-4cea-bb18-a3a518422ede -4.945284911855279
# EstimatorJob: d21563e3-33bc-4c34-9782-09eb90785509
# Job Value: d21563e3-33bc-4c34-9782-09eb90785509 -3.2600060474913706
# EstimatorJob: 6d919ac7-a1b6-4928-a2ef-24ed832c755d
# Job Value: 6d919ac7-a1b6-4928-a2ef-24ed832c755d -4.476613888734059
# EstimatorJob: 8f36d5e3-cd72-4d5f-a65d-82a554023545
# Job Value: 8f36d5e3-cd72-4d5f-a65d-82a554023545 -4.769240712766344
# EstimatorJob: b056d910-5c92-45ed-a196-b472462ab034
# Job Value: b056d910-5c92-45ed-a196-b472462ab034 -4.438854931465409
# EstimatorJob: 66d679f2-0cd9-4bfd-b915-63da966e7bd2
# Job Value: 66d679f2-0cd9-4bfd-b915-63da966e7bd2 -4.617240157857163
# EstimatorJob: 9609b011-9ea2-4c78-98da-94b42fe52bfd
# Job Value: 9609b011-9ea2-4c78-98da-94b42fe52bfd -4.114058112005202
# EstimatorJob: c00cf94f-830f-4e27-ac3e-722379f48107
# Job Value: c00cf94f-830f-4e27-ac3e-722379f48107 -5.271798655107829
# EstimatorJob: 134cebb2-0fa1-4433-9ea5-b7451f09793e
# Job Value: 134cebb2-0fa1-4433-9ea5-b7451f09793e -5.591547967329297
# EstimatorJob: 5181eae2-439d-4498-9f12-abd62591bbca
# Job Value: 5181eae2-439d-4498-9f12-abd62591bbca -4.584273101695357
# EstimatorJob: d87d51c7-ed48-40e2-b909-427b8a86b77b
# Job Value: d87d51c7-ed48-40e2-b909-427b8a86b77b -5.396621157106497
# EstimatorJob: b49d0e73-f999-40c7-9523-5ad28e80e5b5
# Job Value: b49d0e73-f999-40c7-9523-5ad28e80e5b5 -4.201662226837743
# EstimatorJob: d2dbaf16-a703-4673-a424-0df33e663c9d
# Job Value: d2dbaf16-a703-4673-a424-0df33e663c9d -4.825802483927707
# EstimatorJob: 073bfb25-3acc-497b-85ef-65001beeee40
# Job Value: 073bfb25-3acc-497b-85ef-65001beeee40 -5.2963912295729605
# EstimatorJob: d174647a-b179-4368-8ae8-101b498bb09a
# Job Value: d174647a-b179-4368-8ae8-101b498bb09a -5.373156205182999
# EstimatorJob: 51852d5d-6ed6-44c9-be25-9393f7680b44
# Job Value: 51852d5d-6ed6-44c9-be25-9393f7680b44 -5.344721624424628
# EstimatorJob: 5aca66e2-3811-4fff-9bbf-53873b7f445b
# Job Value: 5aca66e2-3811-4fff-9bbf-53873b7f445b -6.293688550248911
# EstimatorJob: eb9be50c-482a-44ce-ab65-9c64478b190c
# Job Value: eb9be50c-482a-44ce-ab65-9c64478b190c -4.321083910833621
# EstimatorJob: acfda1cb-1423-4f42-b210-c0458ab3efa5
# Job Value: acfda1cb-1423-4f42-b210-c0458ab3efa5 -5.961216546578777
# EstimatorJob: 73303aec-5592-4107-9d6c-082d3b401f62
# Job Value: 73303aec-5592-4107-9d6c-082d3b401f62 -5.092307502987395
# EstimatorJob: 12a5231f-7856-4cca-90b4-717c017195a5
# Job Value: 12a5231f-7856-4cca-90b4-717c017195a5 -6.66274049244224
# EstimatorJob: 8c607478-943b-4b9f-8a66-436a608af59e
# Job Value: 8c607478-943b-4b9f-8a66-436a608af59e -4.8090588157746215
# EstimatorJob: 63bf334c-69da-4f71-9714-34ce6278bfc3
# Job Value: 63bf334c-69da-4f71-9714-34ce6278bfc3 -5.7827571439538845
# EstimatorJob: fffd0f74-4446-4f1d-9733-64affb9f2819
# Job Value: fffd0f74-4446-4f1d-9733-64affb9f2819 -6.790841230929386
# EstimatorJob: 6b838e07-5e6e-4ca9-b5b4-b65444bf39ff
# Job Value: 6b838e07-5e6e-4ca9-b5b4-b65444bf39ff -5.471955985725471
# EstimatorJob: 91e0cc11-2e8c-4359-b32e-c56853efc8e8
# Job Value: 91e0cc11-2e8c-4359-b32e-c56853efc8e8 -6.350354143355925
# EstimatorJob: 62906b85-d79c-4f9d-9dad-579178742a69
# Job Value: 62906b85-d79c-4f9d-9dad-579178742a69 -6.384993439994741
# EstimatorJob: 3504c913-6e56-40e6-abc5-468a6aa66c49
# Job Value: 3504c913-6e56-40e6-abc5-468a6aa66c49 -5.8277817639246
# EstimatorJob: bcbcdd9b-8a1a-4c69-8580-aab3ab381a35
# Job Value: bcbcdd9b-8a1a-4c69-8580-aab3ab381a35 -6.503588589230393
# EstimatorJob: 0ad7f609-ab9b-4420-a835-646ae369fd6e
# Job Value: 0ad7f609-ab9b-4420-a835-646ae369fd6e -6.018984208467378
# EstimatorJob: 75cc724f-1f9b-45cc-b6bd-82754dadd58e
# Job Value: 75cc724f-1f9b-45cc-b6bd-82754dadd58e -6.110768250508429
# EstimatorJob: de4e0cb8-0971-4bbc-87e5-2cb8a117faac
# Job Value: de4e0cb8-0971-4bbc-87e5-2cb8a117faac -6.127423778167159
# EstimatorJob: 39fa452b-fda1-4726-93ce-414c14c5e01d
# Job Value: 39fa452b-fda1-4726-93ce-414c14c5e01d -5.93525962121865
# EstimatorJob: 54bcf919-31b9-42dc-8185-56e4a9030cfe
# Job Value: 54bcf919-31b9-42dc-8185-56e4a9030cfe -6.507342132129046
# EstimatorJob: a491b50e-1440-4f54-a1e8-c0ac3176dfc7
# Job Value: a491b50e-1440-4f54-a1e8-c0ac3176dfc7 -6.712496512585307
# EstimatorJob: 9dd12b2b-c515-47a2-9f1c-ed72fd1070e7
# Job Value: 9dd12b2b-c515-47a2-9f1c-ed72fd1070e7 -6.188767431312998
# EstimatorJob: f19ba304-08e6-4890-939d-56ac160e7c01
# Job Value: f19ba304-08e6-4890-939d-56ac160e7c01 -6.9659163046593475
# EstimatorJob: aa8c2e24-ae36-443a-a735-c5b0c4cd35d0
# Job Value: aa8c2e24-ae36-443a-a735-c5b0c4cd35d0 -5.969788937322423
# EstimatorJob: 3fbfc82a-469a-4f30-b99a-c9eb86139e15
# Job Value: 3fbfc82a-469a-4f30-b99a-c9eb86139e15 -6.55825695937489
# EstimatorJob: de9d55b4-4b5b-4703-bfe7-58f289b03987
# Job Value: de9d55b4-4b5b-4703-bfe7-58f289b03987 -6.395499731597963
# EstimatorJob: a634eeb7-d4c4-4f9f-ba45-95c378495873
# Job Value: a634eeb7-d4c4-4f9f-ba45-95c378495873 -7.190943218537901
# EstimatorJob: 582ff266-b43d-4309-bd6e-cb72802416bc
# Job Value: 582ff266-b43d-4309-bd6e-cb72802416bc -6.150515375705435
# EstimatorJob: f8b5fb1d-5482-4b76-9c63-92b1a0713074
# Job Value: f8b5fb1d-5482-4b76-9c63-92b1a0713074 -5.756101090476997
# EstimatorJob: c467fe37-963e-415c-bb39-74468ecfec4d
# Job Value: c467fe37-963e-415c-bb39-74468ecfec4d -7.0211127117432
# EstimatorJob: 7109731f-2ba7-4e65-b705-8566de2f8afa
# Job Value: 7109731f-2ba7-4e65-b705-8566de2f8afa -6.397968777281021
# EstimatorJob: a4ae8468-59c5-46de-beaf-48000ea048e1
# Job Value: a4ae8468-59c5-46de-beaf-48000ea048e1 -6.7842864082514005
# EstimatorJob: 92cac52f-f0a6-470d-814f-b42d6349a3b6
# Job Value: 92cac52f-f0a6-470d-814f-b42d6349a3b6 -5.945830969466797
# EstimatorJob: 40416baa-6c99-459f-b44f-d3f969fcebd7
# Job Value: 40416baa-6c99-459f-b44f-d3f969fcebd7 -7.138740420638598
# EstimatorJob: bc3d1100-991c-42a8-a1ec-54441b117f72
# Job Value: bc3d1100-991c-42a8-a1ec-54441b117f72 -7.3370317603384665
# EstimatorJob: 675164ac-06ef-4d0d-9fbb-e5009c2272e9
# Job Value: 675164ac-06ef-4d0d-9fbb-e5009c2272e9 -5.515587724827352
# EstimatorJob: f09705ec-3dc8-4a3f-af30-0b22efe19fb4
# Job Value: f09705ec-3dc8-4a3f-af30-0b22efe19fb4 -6.999876007220267
# EstimatorJob: a93477bb-581d-4f84-97e8-1543eba21f3c
# Job Value: a93477bb-581d-4f84-97e8-1543eba21f3c -6.7078540283839425
# EstimatorJob: fbf25d87-e5d3-4537-9161-5bddfdfac677
# Job Value: fbf25d87-e5d3-4537-9161-5bddfdfac677 -6.471824017996881
# EstimatorJob: 788278ec-4fbf-4124-9cf6-dd2229d27015
# Job Value: 788278ec-4fbf-4124-9cf6-dd2229d27015 -7.3470236829327025
# EstimatorJob: 82efcb4d-1c94-497e-9f0d-fb72785222d4
# Job Value: 82efcb4d-1c94-497e-9f0d-fb72785222d4 -7.361260203680306
# EstimatorJob: 707dd70c-0caf-44a3-97b7-5bbff72f372f
# Job Value: 707dd70c-0caf-44a3-97b7-5bbff72f372f -6.836810248493847
# EstimatorJob: c65b1cf0-6c38-41c7-be82-007be505328a
# Job Value: c65b1cf0-6c38-41c7-be82-007be505328a -7.605561851895773
# EstimatorJob: d1bcc404-b820-417e-8247-b76a374f2dc5
# Job Value: d1bcc404-b820-417e-8247-b76a374f2dc5 -6.485128025666593
# EstimatorJob: 4ca750e5-55ea-4efa-9034-03896cb2fff4
# Job Value: 4ca750e5-55ea-4efa-9034-03896cb2fff4 -7.07512226357754
# EstimatorJob: 6c1d288d-70fb-475d-91c1-21ed703b4205
# Job Value: 6c1d288d-70fb-475d-91c1-21ed703b4205 -7.359186674352211
# EstimatorJob: 95543ea1-2cf8-4e2d-8aa7-63e9e9f8af9e
# Job Value: 95543ea1-2cf8-4e2d-8aa7-63e9e9f8af9e -7.505525714394316
# EstimatorJob: e0ab9c95-0f17-4eb2-b1cb-d5120ee00963
# Job Value: e0ab9c95-0f17-4eb2-b1cb-d5120ee00963 -6.241810559036077
# EstimatorJob: 2d047d1c-e893-4c31-87d8-d936e399363a
# Job Value: 2d047d1c-e893-4c31-87d8-d936e399363a -7.4781822880168045
# EstimatorJob: 936554d6-86e1-48cb-a6e7-11c4a6f1fbb8
# Job Value: 936554d6-86e1-48cb-a6e7-11c4a6f1fbb8 -6.889409305256244
# EstimatorJob: b2581b2c-d0b5-43a3-9860-b102c5c9cc22
# Job Value: b2581b2c-d0b5-43a3-9860-b102c5c9cc22 -8.045487116826635
# {   'aux_operator_eigenvalues': None,
#     'cost_function_evals': 150,
#     'eigenstate': None,
#     'eigenvalue': -8.045487116826635,
#     'optimal_circuit': None,
#     'optimal_parameters': array([ 0.16458826,  0.71972868,  0.78779561,  2.12558472,  0.77326987,
#        -0.27654035,  0.70309247,  2.33814271, -1.31261107,  0.78886383,
#         1.05141498,  1.05935763,  1.03406295,  1.80177921, -0.93619513,
#        -0.4797378 , -0.31434534, -0.19910146, -0.22346398, -0.41516688,
#        -1.6665052 ,  0.93315768,  0.40520761,  2.77922785, -0.45652704,
#        -0.93795274,  0.23817472,  2.12425725,  0.72647392,  0.19407273,
#        -0.09949473,  0.59019899, -0.61622501, -0.54355583,  0.34013174,
#         0.21901058,  1.68843051, -0.16919208, -0.86274038,  0.25599344,
#         0.51877496, -0.9992974 ,  1.41413521, -1.88715337,  2.26065392,
#         0.47801928,  1.36649938,  0.7621586 ]),
#     'optimal_point': None,
#     'optimal_value': None,
#     'optimizer_evals': None,
#     'optimizer_result': None,
#     'optimizer_time': None}
# execution time (s): 45.42

# %% [markdown]
# In the print out above, the ground state energy is under "eigenvalue", and the optimal choice of parameters that goes with that energy is under "optimal_parameters". Let's plot the energy convergence data the callback function acquired.

# %%
plt.plot(intermediate_info, color='purple', lw=2, label='Simulated VQE')
plt.ylabel('Energy')
plt.xlabel('Iterations')
# Exact ground state energy value
plt.axhline(y=gs_energy, color="tab:red", ls="--", lw=2, label="Target: " + str(gs_energy))
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# The true ground state energy is -18.0. As a metric for how well the VQE found the ground state energy, we will compute the relative difference between -18.0 and what we just achieved with VQE. This will be the metric of performance in the judging criteria, though it's important to note that it's not the only useful metric when working with VQE. Remember that the lower the relative error the higher you will score.

# %%
def rel_err(target, measured):
    return abs((target - measured) / target)

# Compute the relative error between the expected ground state energy and the VQE's output
rel_error = rel_err(gs_energy, result.eigenvalue)

print(f'Expected ground state energy: {gs_energy:.10f}')
print(f'Computed ground state energy: {result.eigenvalue:.10f}')
print(f'Relative error: {rel_error:.8f}')
# Out:
# Expected ground state energy: -18.0000000000
# Computed ground state energy: -8.0454871168
# Relative error: 0.55302849

# %% [markdown]
# ## 3-1 Qiskit runtime (cloud simulator)
#
# Next we demonstrate how to run VQE using [qiskit_ibm_runtime](https://github.com/Qiskit/qiskit-ibm-runtime) **which has different syntax from qiskit terra's runtime**. The qiskit_ibm_runtime module includes the same programming model as qiskit terra, but qiskit_ibm_runtime has access to a cloud simulator and more importantly the ibmq_guadalupe device. To learn more about qiskit_ibm_runtime check out these tutorials from the docs: [a tutorial on the estimator](https://github.com/Qiskit/qiskit-ibm-runtime/blob/main/docs/tutorials/how-to-getting-started-with-estimator.ipynb) and [a tutorial on the sampler](https://github.com/Qiskit/qiskit-ibm-runtime/blob/main/docs/tutorials/how-to-getting-started-with-sampler.ipynb).
#
# We will use all the same VQE components we've built up so far, but the syntax for executing on the hardware is wrapped in [a session](https://quantum-computing.ibm.com/lab/docs/iql/manage/systems/sessions/) as shown in the following cells.
#
# We first demonstrate running VQE with the cloud simulator backend to check everything is working correctly. This may take a few minutes. After running on the cloud simulator, we make a simple switch of backends to the real ibmq_guadalupe device to get the final result. Depending on how your VQE is setup, this may take a couple hours.

# %%
from qiskit_ibm_runtime import (QiskitRuntimeService, Session,
                                Estimator as RuntimeEstimator)
from qiskit import Aer

# Save an IBM Quantum account. See docs for credential security warning
# https://github.com/Qiskit/qiskit-ibm-runtime/tree/stable/0.7#saving-account-on-disk
# QiskitRuntimeService.save_account(channel="ibm_quantum", token="MY_IBM_QUANTUM_TOKEN")
service = QiskitRuntimeService(channel='ibm_quantum')

# %%
# print available backend and select one
print('Simulators:', service.backends(simulator=True))

# Select a simulator backend
backend = 'simulator_statevector'
# Out:
# Simulators: [<IBMBackend('ibmq_qasm_simulator')>, <IBMBackend('simulator_statevector')>, <IBMBackend('simulator_mps')>, <IBMBackend('simulator_extended_stabilizer')>, <IBMBackend('simulator_stabilizer')>]

# %%
# Define a simple callback function
intermediate_info_sim_backend = []
def callback_sim(value):
        intermediate_info_sim_backend.append(value)

# %%
optimizer = SPSA(75)

# %%
import signal, time

from qiskit_ibm_runtime import Estimator, Session
from qiskit.providers import JobStatus

def timeout_handler(signum, frame):
    raise Exception('Iteration timed out')
    
class RetryEstimator(Estimator):
    """RuntimeRetryEstimator class.
    
    This class inherits from Qiskit IBM Runtime's Estimator and overwrites its run method such that it retries calling it
    a maximum of 'max_retries' consecutive times, if it encounters one of the following randomly occuring errors:
    
    * An Estimator error (in this case "Job.ERROR" is printed, and the job is cancelled automatically)
    * A timeout error where the job either remains running or completes but does not return anything, for a time larger 
      than 'timeout' (in this case the job is cancelled by the patch and "Job.CANCELLED" is printed)
    * A creation error, where the job fails to be created because connection is lost between the runtime server and the
      quantum computer (in this case "Failed to create job." is printed). If this error occurs, the patch connects the user
      to a new Session (to be handled with care! also, this will unfortunately put the next job in the queue). 
    """
    
    def __init__(self, *args, max_retries: int = 5, timeout: int = 3600, **kwargs) -> None:
        super().__init__(*args, **kwargs)
        self.max_retries = max_retries
        self.timeout = timeout
        self.backend = super().session._backend
        signal.signal(signal.SIGALRM, timeout_handler)
    
    def run(self, circuits, observables, parameter_values, **kwargs):
        result = None
        for i in range(self.max_retries):
            try:
                job = super().run(circuits, observables, parameter_values, **kwargs)
                while job.status() in [JobStatus.INITIALIZING, JobStatus.QUEUED, JobStatus.VALIDATING]:
                    time.sleep(5) # Check every 5 seconds whether job status has changed
                signal.alarm(self.timeout) # Once job starts running, set timeout to 1 hour by default
                result = job.result()
                if result is not None:
                    signal.alarm(0) # reset timer
                    return job
            except Exception as e:
                print("\nSomething went wrong...")
                print(f"\n\nERROR MESSAGE:\n{e}\n\n")
                if 'job' in locals(): # Sometimes job fails to create
                    print(f"Job ID: {job.job_id}. Job status: {job.status()}.")
                    if job.status() not in [JobStatus.DONE, JobStatus.ERROR, JobStatus.CANCELLED]:
                        job.cancel()
                else:
                    print("Failed to create job.")
                print(f"Starting trial number {i+2}...\n")
                print(f"Creating new session...\n")
                signal.alarm(0) # reset timer
                super().session.close()
                self._session = Session(backend=self.backend)
        if result is None:
            raise RuntimeError(f"Program failed! Maximum number of retries ({self.max_retries}) exceeded")

# %%
'''
init_data = np.array([ 1.51486831,  0.64781744,  1.91301699,  1.53925002,  0.43530487,
       -1.65264869,  1.99354643, -0.690795  , -1.30345513,  1.04451712,
        2.73353243,  1.58871966, -0.44923815,  1.69517272,  0.3430029 ,
        0.96734844,  1.44255542,  1.36418201,  1.94543774, -1.92104182,
        1.7259811 ,  0.75667478,  1.61075242,  0.61045154, -0.3754985 ,
        0.58718292,  0.84652091,  0.01935209, -1.74895118, -0.36197877,
       -1.11669845,  1.67897504, -0.71293888,  0.57091265,  0.26844579,
       -0.41044373,  1.83821108,  2.64720273,  0.38305837,  0.0638966 ,
        0.61122281, -1.50953775, -0.57552455,  1.97298415, -0.96018021,
        0.64097591, -0.40804849,  1.72214388])

'''
init_data = result.optimal_parameters

# %%
# Setup Estimator with session error handling reconnection work around
start = time.time()
with Session(service=service, backend=backend) as session:
    # Prepare extended primitive
    rt_estimator = RetryEstimator(session=session)
    # set up algorithm
    custom_vqe = CustomVQE(rt_estimator, ansatz_opt, optimizer, callback=callback_sim, init_data=init_data)
    # run algorithm
    result = custom_vqe.compute_minimum_eigenvalue(ham_16)
end = time.time()
print(result, f'execution time (s): {end - start:.2f}')
# Out:
# EstimatorJob: cfpn9l7lq5soddt7gsc0
# Job Value: cfpn9l7lq5soddt7gsc0 -6.155000000000001
# EstimatorJob: cfpn9mvlq5soddt7gt2g
# Job Value: cfpn9mvlq5soddt7gt2g -7.116
# EstimatorJob: cfpn9nvlq5soddt7gtig
# Job Value: cfpn9nvlq5soddt7gtig -6.539999999999999
# EstimatorJob: cfpn9pmuqale1rid2kf0
# Job Value: cfpn9pmuqale1rid2kf0 -6.532
# EstimatorJob: cfpn9qgmkkjip78pnu0g
# Job Value: cfpn9qgmkkjip78pnu0g -6.906000000000001
# EstimatorJob: cfpn9sgmkkjip78pnun0
# Job Value: cfpn9sgmkkjip78pnun0 -6.645
# EstimatorJob: cfpn9teh59a88pa0gdr0
# Job Value: cfpn9teh59a88pa0gdr0 -4.662999999999999
# EstimatorJob: cfpn9veuqale1rid2n10
# Job Value: cfpn9veuqale1rid2n10 -8.324
# EstimatorJob: cfpna0fnsade071559t0
# Job Value: cfpna0fnsade071559t0 -6.330000000000001
# EstimatorJob: cfpna2fnsade07155au0
# Job Value: cfpna2fnsade07155au0 -6.86
# EstimatorJob: cfpna38mkkjip78po220
# Job Value: cfpna38mkkjip78po220 -5.497
# EstimatorJob: cfpna56h59a88pa0gh8g
# Job Value: cfpna56h59a88pa0gh8g -6.994
# EstimatorJob: cfpna6mh59a88pa0ghv0
# Job Value: cfpna6mh59a88pa0ghv0 -6.904
# EstimatorJob: cfpna86uqale1rid2qi0
# Job Value: cfpna86uqale1rid2qi0 -6.236000000000001
# EstimatorJob: cfpna9euqale1rid2r60
# Job Value: cfpna9euqale1rid2r60 -6.899000000000001
# EstimatorJob: cfpnaafnsade07155ej0
# Job Value: cfpnaafnsade07155ej0 -6.174999999999999
# EstimatorJob: cfpnacksiq6vn3fg1hc0
# Job Value: cfpnacksiq6vn3fg1hc0 -5.845999999999999
# EstimatorJob: cfpnadvlq5soddt7h6p0
# Job Value: cfpnadvlq5soddt7h6p0 -5.199000000000001
# EstimatorJob: cfpnafuuqale1rid2tt0
# Job Value: cfpnafuuqale1rid2tt0 -6.281
# EstimatorJob: cfpnaigmkkjip78po8t0
# Job Value: cfpnaigmkkjip78po8t0 -6.68
# EstimatorJob: cfpnajflq5soddt7h9a0
# Job Value: cfpnajflq5soddt7h9a0 -5.531
# EstimatorJob: cfpnakuuqale1rid307g
# Job Value: cfpnakuuqale1rid307g -5.987
# EstimatorJob: cfpnammuqale1rid30sg
# Job Value: cfpnammuqale1rid30sg -6.354
# EstimatorJob: cfpnap8mkkjip78pobug
# Job Value: cfpnap8mkkjip78pobug -6.332
# EstimatorJob: cfpnaqfnsade07155ltg
# Job Value: cfpnaqfnsade07155ltg -6.217
# EstimatorJob: cfpnas0mkkjip78podg0
# Job Value: cfpnas0mkkjip78podg0 -5.0569999999999995
# EstimatorJob: cfpnat7nsade07155n4g
# Job Value: cfpnat7nsade07155n4g -6.3420000000000005
# EstimatorJob: cfpnaufnsade07155nq0
# Job Value: cfpnaufnsade07155nq0 -5.726
# EstimatorJob: cfpnavnlq5soddt7hedg
# Job Value: cfpnavnlq5soddt7hedg -5.356
# EstimatorJob: cfpnb26uqale1rid35f0
# Job Value: cfpnb26uqale1rid35f0 -6.628
# EstimatorJob: cfpnb46h59a88pa0gumg
# Job Value: cfpnb46h59a88pa0gumg -6.398999999999999
# EstimatorJob: cfpnb54siq6vn3fg1skg
# Job Value: cfpnb54siq6vn3fg1skg -6.479000000000001
# EstimatorJob: cfpnb77lq5soddt7hh80
# Job Value: cfpnb77lq5soddt7hh80 -5.857
# EstimatorJob: cfpnb86uqale1rid37sg
# Job Value: cfpnb86uqale1rid37sg -7.1
# EstimatorJob: cfpnb98mkkjip78pojj0
# Job Value: cfpnb98mkkjip78pojj0 -6.332000000000001
# EstimatorJob: cfpnbannsade07155sqg
# Job Value: cfpnbannsade07155sqg -5.456
# EstimatorJob: cfpnbc4siq6vn3fg2030
# Job Value: cfpnbc4siq6vn3fg2030 -7.164999999999999
# EstimatorJob: cfpnbdnlq5soddt7hjsg
# Job Value: cfpnbdnlq5soddt7hjsg -6.147
# EstimatorJob: cfpnbfeh59a88pa0h3hg
# Job Value: cfpnbfeh59a88pa0h3hg -5.603
# EstimatorJob: cfpnbhmh59a88pa0h4dg
# Job Value: cfpnbhmh59a88pa0h4dg -6.055
# EstimatorJob: cfpnbigmkkjip78ponp0
# Job Value: cfpnbigmkkjip78ponp0 -5.61
# EstimatorJob: cfpnbknnsade0715617g
# Job Value: cfpnbknnsade0715617g -6.832000000000001
# EstimatorJob: cfpnblnlq5soddt7hnk0
# Job Value: cfpnblnlq5soddt7hnk0 -6.272
# EstimatorJob: cfpnbofnsade07156370
# Job Value: cfpnbofnsade07156370 -5.21
# EstimatorJob: cfpnbqeh59a88pa0h8ig
# Job Value: cfpnbqeh59a88pa0h8ig -5.553
# EstimatorJob: cfpnbrcsiq6vn3fg277g
# Job Value: cfpnbrcsiq6vn3fg277g -6.897
# EstimatorJob: cfpnbsgmkkjip78poskg
# Job Value: cfpnbsgmkkjip78poskg -7.507999999999999
# EstimatorJob: cfpnbtuuqale1rid3hl0
# Job Value: cfpnbtuuqale1rid3hl0 -5.973000000000001
# EstimatorJob: cfpnbv8mkkjip78pou0g
# Job Value: cfpnbv8mkkjip78pou0g -5.523000000000001
# EstimatorJob: cfpnc0mh59a88pa0hbeg
# Job Value: cfpnc0mh59a88pa0hbeg -5.5600000000000005
# EstimatorJob: cfpnc26h59a88pa0hc00
# Job Value: cfpnc26h59a88pa0hc00 -4.609
# EstimatorJob: cfpnc5nlq5soddt7hu1g
# Job Value: cfpnc5nlq5soddt7hu1g -8.055
# EstimatorJob: cfpnc6nlq5soddt7huk0
# Job Value: cfpnc6nlq5soddt7huk0 0.23000000000000004
# EstimatorJob: cfpnc87nsade07156a3g
# Job Value: cfpnc87nsade07156a3g 0.16499999999999998
# EstimatorJob: cfpnc9ssiq6vn3fg2ehg
# Job Value: cfpnc9ssiq6vn3fg2ehg 0.29300000000000015
# EstimatorJob: cfpncbuuqale1rid3nog
# Job Value: cfpncbuuqale1rid3nog -0.6309999999999998
# EstimatorJob: cfpnccuh59a88pa0hh6g
# Job Value: cfpnccuh59a88pa0hh6g -0.508
# EstimatorJob: cfpncemh59a88pa0hi50
# Job Value: cfpncemh59a88pa0hi50 -0.9640000000000001
# EstimatorJob: cfpncfksiq6vn3fg2hng
# Job Value: cfpncfksiq6vn3fg2hng 0.3619999999999998
# EstimatorJob: cfpncheh59a88pa0hjq0
# Job Value: cfpncheh59a88pa0hjq0 -2.2310000000000003
# EstimatorJob: cfpnciksiq6vn3fg2j90
# Job Value: cfpnciksiq6vn3fg2j90 -1.7049999999999996
# EstimatorJob: cfpnclssiq6vn3fg2kr0
# Job Value: cfpnclssiq6vn3fg2kr0 -1.3089999999999997
# EstimatorJob: cfpncn8mkkjip78ppa8g
# Job Value: cfpncn8mkkjip78ppa8g -1.6159999999999999
# EstimatorJob: cfpncofnsade07156i5g
# Job Value: cfpncofnsade07156i5g -1.5499999999999998
# EstimatorJob: cfpncs6h59a88pa0hovg
# Job Value: cfpncs6h59a88pa0hovg -1.041
# EstimatorJob: cfpncu6uqale1rid3vtg
# Job Value: cfpncu6uqale1rid3vtg -1.9799999999999995
# EstimatorJob: cfpncuuh59a88pa0hqfg
# Job Value: cfpncuuh59a88pa0hqfg -2.321
# EstimatorJob: cfpnd1muqale1rid419g
# Job Value: cfpnd1muqale1rid419g -1.0429999999999997
# EstimatorJob: cfpnd46h59a88pa0hss0
# Job Value: cfpnd46h59a88pa0hss0 -0.952
# EstimatorJob: cfpnd6csiq6vn3fg2rv0
# Job Value: cfpnd6csiq6vn3fg2rv0 -2.313
# EstimatorJob: cfpnd7muqale1rid43o0
# Job Value: cfpnd7muqale1rid43o0 -3.6879999999999997
# EstimatorJob: cfpnd9fnsade07156on0
# Job Value: cfpnd9fnsade07156on0 -2.222
# EstimatorJob: cfpndaeh59a88pa0i000
# Job Value: cfpndaeh59a88pa0i000 -2.78
# EstimatorJob: cfpndbnlq5soddt7ies0
# Job Value: cfpndbnlq5soddt7ies0 -2.609
# EstimatorJob: cfpndd8mkkjip78ppk1g
# Job Value: cfpndd8mkkjip78ppk1g -2.7170000000000005
# EstimatorJob: cfpndeeh59a88pa0i1qg
# Job Value: cfpndeeh59a88pa0i1qg -3.106
# EstimatorJob: cfpndhksiq6vn3fg3130
# Job Value: cfpndhksiq6vn3fg3130 -3.767
# EstimatorJob: cfpndj7nsade07156sug
# Job Value: cfpndj7nsade07156sug -2.6759999999999997
# EstimatorJob: cfpndk4siq6vn3fg3270
# Job Value: cfpndk4siq6vn3fg3270 -2.4239999999999995
# EstimatorJob: cfpndlomkkjip78ppns0
# Job Value: cfpndlomkkjip78ppns0 -4.2299999999999995
# EstimatorJob: cfpndnfnsade07156uo0
# Job Value: cfpndnfnsade07156uo0 -2.399
# EstimatorJob: cfpndoeh59a88pa0i66g
# Job Value: cfpndoeh59a88pa0i66g -3.145
# EstimatorJob: cfpndpksiq6vn3fg34p0
# Job Value: cfpndpksiq6vn3fg34p0 -3.0700000000000003
# EstimatorJob: cfpndr7nsade071570e0
# Job Value: cfpndr7nsade071570e0 -2.318
# EstimatorJob: cfpndsfnsade07157130
# Job Value: cfpndsfnsade07157130 -3.769
# EstimatorJob: cfpndv6uqale1rid4ebg
# Job Value: cfpndv6uqale1rid4ebg -1.681
# EstimatorJob: cfpne4euqale1rid4gk0
# Job Value: cfpne4euqale1rid4gk0 -3.7030000000000003
# EstimatorJob: cfpnec7nsade071577n0
# Job Value: cfpnec7nsade071577n0 -4.078
# EstimatorJob: cfpneossiq6vn3fg3ie0
# Job Value: cfpneossiq6vn3fg3ie0 -3.5969999999999995
# EstimatorJob: cfpnf3fnsade07157hp0
# Job Value: cfpnf3fnsade07157hp0 -3.56
# EstimatorJob: cfpnf4nlq5soddt7j6hg
# Job Value: cfpnf4nlq5soddt7j6hg -3.4799999999999995
# EstimatorJob: cfpnf80mkkjip78pqdcg
# Job Value: cfpnf80mkkjip78pqdcg -3.498
# EstimatorJob: cfpnf9mh59a88pa0ire0
# Job Value: cfpnf9mh59a88pa0ire0 -3.755
# EstimatorJob: cfpnfannsade07157ks0
# Job Value: cfpnfannsade07157ks0 -3.755
# EstimatorJob: cfpnfcmuqale1rid51p0
# Job Value: cfpnfcmuqale1rid51p0 -3.482
# EstimatorJob: cfpnfe4siq6vn3fg3s6g
# Job Value: cfpnfe4siq6vn3fg3s6g -3.3770000000000002
# EstimatorJob: cfpnff8mkkjip78pqgpg
# Job Value: cfpnff8mkkjip78pqgpg -3.833
# EstimatorJob: cfpnfg0mkkjip78pqhb0
# Job Value: cfpnfg0mkkjip78pqhb0 -3.383
# EstimatorJob: cfpnfh0mkkjip78pqhng
# Job Value: cfpnfh0mkkjip78pqhng -4.551
# EstimatorJob: cfpnfiomkkjip78pqigg
# Job Value: cfpnfiomkkjip78pqigg -2.813
# EstimatorJob: cfpnfjomkkjip78pqj6g
# Job Value: cfpnfjomkkjip78pqj6g -4.148
# EstimatorJob: cfpnfo7nsade07157r1g
# Job Value: cfpnfo7nsade07157r1g -3.8640000000000003
# EstimatorJob: cfpnfpgmkkjip78pqmd0
# Job Value: cfpnfpgmkkjip78pqmd0 -3.441
# EstimatorJob: cfpnfqnlq5soddt7jgfg
# Job Value: cfpnfqnlq5soddt7jgfg -3.672
# EstimatorJob: cfpnftfnsade07157ti0
# Job Value: cfpnftfnsade07157ti0 -4.157
# EstimatorJob: cfpnfueh59a88pa0j4ug
# Job Value: cfpnfueh59a88pa0j4ug -4.075
# EstimatorJob: cfpng0uh59a88pa0j670
# Job Value: cfpng0uh59a88pa0j670 -4.155
# EstimatorJob: cfpng3eh59a88pa0j740
# Job Value: cfpng3eh59a88pa0j740 -3.2359999999999998
# EstimatorJob: cfpng56h59a88pa0j7vg
# Job Value: cfpng56h59a88pa0j7vg -3.4529999999999994
# EstimatorJob: cfpng6mh59a88pa0j8jg
# Job Value: cfpng6mh59a88pa0j8jg -3.403
# EstimatorJob: cfpng97lq5soddt7jmqg
# Job Value: cfpng97lq5soddt7jmqg -3.242000000000001
# EstimatorJob: cfpngaeuqale1rid5eh0
# Job Value: cfpngaeuqale1rid5eh0 -3.5180000000000002
# EstimatorJob: cfpngbvnsade071584b0
# Job Value: cfpngbvnsade071584b0 -3.473
# EstimatorJob: cfpngcvnsade071584s0
# Job Value: cfpngcvnsade071584s0 -3.2350000000000003
# EstimatorJob: cfpngemuqale1rid5g80
# Job Value: cfpngemuqale1rid5g80 -4.291
# EstimatorJob: cfpngfnnsade0715862g
# Job Value: cfpngfnnsade0715862g -4.25
# EstimatorJob: cfpngggmkkjip78pr1fg
# Job Value: cfpngggmkkjip78pr1fg -3.0730000000000004
# EstimatorJob: cfpnghgmkkjip78pr1v0
# Job Value: cfpnghgmkkjip78pr1v0 -3.968
# EstimatorJob: cfpngjeuqale1rid5ieg
# Job Value: cfpngjeuqale1rid5ieg -3.533000000000001
# EstimatorJob: cfpngkfnsade071588cg
# Job Value: cfpngkfnsade071588cg -4.387
# EstimatorJob: cfpnglnlq5soddt7js9g
# Job Value: cfpnglnlq5soddt7js9g -4.975999999999999
# EstimatorJob: cfpngn0mkkjip78pr4g0
# Job Value: cfpngn0mkkjip78pr4g0 -3.4059999999999997
# EstimatorJob: cfpngoeh59a88pa0jglg
# Job Value: cfpngoeh59a88pa0jglg -4.515
# EstimatorJob: cfpngpssiq6vn3fg4gg0
# Job Value: cfpngpssiq6vn3fg4gg0 -3.581
# EstimatorJob: cfpngquh59a88pa0jhm0
# Job Value: cfpngquh59a88pa0jhm0 -3.3099999999999996
# EstimatorJob: cfpngrvnsade07158bp0
# Job Value: cfpngrvnsade07158bp0 -5.4959999999999996
# EstimatorJob: cfpngtfnsade07158cc0
# Job Value: cfpngtfnsade07158cc0 -4.669
# EstimatorJob: cfpngugmkkjip78pr89g
# Job Value: cfpngugmkkjip78pr89g -3.135
# EstimatorJob: cfpnh0uuqale1rid5o3g
# Job Value: cfpnh0uuqale1rid5o3g -3.3179999999999996
# EstimatorJob: cfpnh27lq5soddt7k1o0
# Job Value: cfpnh27lq5soddt7k1o0 -4.242999999999999
# EstimatorJob: cfpnh3nnsade07158fd0
# Job Value: cfpnh3nnsade07158fd0 -4.173
# EstimatorJob: cfpnh48mkkjip78prb7g
# Job Value: cfpnh48mkkjip78prb7g -4.294999999999999
# EstimatorJob: cfpnh6fnsade07158gs0
# Job Value: cfpnh6fnsade07158gs0 -3.9219999999999997
# EstimatorJob: cfpnh7flq5soddt7k430
# Job Value: cfpnh7flq5soddt7k430 -5.069999999999999
# EstimatorJob: cfpnh84siq6vn3fg4n5g
# Job Value: cfpnh84siq6vn3fg4n5g -4.763999999999999
# EstimatorJob: cfpnh97nsade07158id0
# Job Value: cfpnh97nsade07158id0 -4.577999999999999
# EstimatorJob: cfpnhamh59a88pa0jo90
# Job Value: cfpnhamh59a88pa0jo90 -4.7010000000000005
# EstimatorJob: cfpnhbcsiq6vn3fg4ou0
# Job Value: cfpnhbcsiq6vn3fg4ou0 -4.205
# EstimatorJob: cfpnhcfnsade07158ju0
# Job Value: cfpnhcfnsade07158ju0 -4.765
# EstimatorJob: cfpnhefnsade07158kug
# Job Value: cfpnhefnsade07158kug -4.834
# EstimatorJob: cfpnhffnsade07158lfg
# Job Value: cfpnhffnsade07158lfg -4.231999999999999
# EstimatorJob: cfpnhguuqale1rid5v40
# Job Value: cfpnhguuqale1rid5v40 -5.5200000000000005
# EstimatorJob: cfpnhi8mkkjip78prho0
# Job Value: cfpnhi8mkkjip78prho0 -5.152
# EstimatorJob: cfpnhjfnsade07158nag
# Job Value: cfpnhjfnsade07158nag -5.505
# EstimatorJob: cfpnhl6uqale1rid615g
# Job Value: cfpnhl6uqale1rid615g -4.941000000000001
# EstimatorJob: cfpnhluh59a88pa0jtig
# Job Value: cfpnhluh59a88pa0jtig -4.609
# EstimatorJob: cfpnhnomkkjip78prk80
# Job Value: cfpnhnomkkjip78prk80 -4.916
# EstimatorJob: cfpnhrcsiq6vn3fg50bg
# Job Value: cfpnhrcsiq6vn3fg50bg -5.002
# EstimatorJob: cfpnhsuuqale1rid64k0
# Job Value: cfpnhsuuqale1rid64k0 -5.162999999999999
# EstimatorJob: cfpnhtomkkjip78prn20
# Job Value: cfpnhtomkkjip78prn20 -5.662
# EstimatorJob: cfpnhv6h59a88pa0k1hg
# Job Value: cfpnhv6h59a88pa0k1hg -4.986000000000001
# EstimatorJob: cfpni17lq5soddt7kffg
# Job Value: cfpni17lq5soddt7kffg -5.81
# EstimatorJob: cfpni3csiq6vn3fg53p0
# Job Value: cfpni3csiq6vn3fg53p0 -4.23
# EstimatorJob: cfpni4flq5soddt7kh2g
# Job Value: cfpni4flq5soddt7kh2g -5.098
# EstimatorJob: cfpni5nlq5soddt7khmg
# Job Value: cfpni5nlq5soddt7khmg -5.579
# EstimatorJob: cfpni6nlq5soddt7ki2g
# Job Value: cfpni6nlq5soddt7ki2g -5.58
# EstimatorJob: cfpni87lq5soddt7kikg
# Job Value: cfpni87lq5soddt7kikg -4.173
# EstimatorJob: cfpni97nsade07159190
# Job Value: cfpni97nsade07159190 -5.258000000000001
# EstimatorJob: cfpnicnnsade071592s0
# Job Value: cfpnicnnsade071592s0 -5.0009999999999994
# EstimatorJob: cfpniecsiq6vn3fg58tg
# Job Value: cfpniecsiq6vn3fg58tg -6.13
# EstimatorJob: cfpnigvlq5soddt7km20
# Job Value: cfpnigvlq5soddt7km20 -5.845000000000001
# EstimatorJob: cfpnii0mkkjip78ps03g
# Job Value: cfpnii0mkkjip78ps03g -4.303999999999999
# EstimatorJob: cfpnij0mkkjip78ps0l0
# Job Value: cfpnij0mkkjip78ps0l0 -6.345000000000001
# EstimatorJob: cfpnikcsiq6vn3fg5c00
# Job Value: cfpnikcsiq6vn3fg5c00 -3.943
# EstimatorJob: cfpnilomkkjip78ps230
# Job Value: cfpnilomkkjip78ps230 -5.1690000000000005
# EstimatorJob: cfpnio7nsade071597tg
# Job Value: cfpnio7nsade071597tg -4.124
# EstimatorJob: cfpnip8mkkjip78ps3i0
# Job Value: cfpnip8mkkjip78ps3i0 -5.514
# EstimatorJob: cfpniqmuqale1rid6h60
# Job Value: cfpniqmuqale1rid6h60 -4.534999999999999
# EstimatorJob: cfpnirnlq5soddt7kqo0
# Job Value: cfpnirnlq5soddt7kqo0 -5.9670000000000005
# EstimatorJob: cfpniu8mkkjip78ps5qg
# Job Value: cfpniu8mkkjip78ps5qg -4.577
# EstimatorJob: cfpnivcsiq6vn3fg5hbg
# Job Value: cfpnivcsiq6vn3fg5hbg -5.7620000000000005
# EstimatorJob: cfpnj0mh59a88pa0kg6g
# Job Value: cfpnj0mh59a88pa0kg6g -4.758
# EstimatorJob: cfpnj26uqale1rid6kjg
# Job Value: cfpnj26uqale1rid6kjg -5.4079999999999995
# EstimatorJob: cfpnj3mh59a88pa0khkg
# Job Value: cfpnj3mh59a88pa0khkg -5.228999999999999
# EstimatorJob: cfpnj57lq5soddt7kuog
# Job Value: cfpnj57lq5soddt7kuog -5.4990000000000006
# EstimatorJob: cfpnj7vnsade07159erg
# Job Value: cfpnj7vnsade07159erg -5.880000000000001
# EstimatorJob: cfpnj8uuqale1rid6ndg
# Job Value: cfpnj8uuqale1rid6ndg -5.691999999999999
# EstimatorJob: cfpnjavnsade07159ga0
# Job Value: cfpnjavnsade07159ga0 -5.007999999999999
# EstimatorJob: cfpnjbvlq5soddt7l1j0
# Job Value: cfpnjbvlq5soddt7l1j0 -6.178999999999999
# EstimatorJob: cfpnjd7lq5soddt7l200
# Job Value: cfpnjd7lq5soddt7l200 -4.732
# EstimatorJob: cfpnjennsade07159ho0
# Job Value: cfpnjennsade07159ho0 -5.546
# EstimatorJob: cfpnjgssiq6vn3fg5p50
# Job Value: cfpnjgssiq6vn3fg5p50 -5.2379999999999995
# EstimatorJob: cfpnjhssiq6vn3fg5pk0
# Job Value: cfpnjhssiq6vn3fg5pk0 -5.178
# EstimatorJob: cfpnjjvnsade07159k4g
# Job Value: cfpnjjvnsade07159k4g -5.289
# EstimatorJob: cfpnjl7nsade07159kpg
# Job Value: cfpnjl7nsade07159kpg -5.4990000000000006
# EstimatorJob: cfpnjnfnsade07159lm0
# Job Value: cfpnjnfnsade07159lm0 -5.207999999999999
# EstimatorJob: cfpnjocsiq6vn3fg5sm0
# Job Value: cfpnjocsiq6vn3fg5sm0 -5.449
# EstimatorJob: cfpnjq6h59a88pa0kr90
# Job Value: cfpnjq6h59a88pa0kr90 -4.984
# EstimatorJob: cfpnjr6uqale1rid6um0
# Job Value: cfpnjr6uqale1rid6um0 -5.550000000000001
# EstimatorJob: cfpnjs8mkkjip78psk3g
# Job Value: cfpnjs8mkkjip78psk3g -5.800999999999999
# EstimatorJob: cfpnju6uqale1rid6vv0
# Job Value: cfpnju6uqale1rid6vv0 -6.205
# EstimatorJob: cfpnk06uqale1rid70rg
# Job Value: cfpnk06uqale1rid70rg -5.778
# EstimatorJob: cfpnk1fnsade07159q8g
# Job Value: cfpnk1fnsade07159q8g -5.67
# EstimatorJob: cfpnk2csiq6vn3fg60q0
# Job Value: cfpnk2csiq6vn3fg60q0 -5.224000000000001
# EstimatorJob: cfpnk3ksiq6vn3fg61h0
# Job Value: cfpnk3ksiq6vn3fg61h0 -5.489
# EstimatorJob: cfpnk4nnsade07159rsg
# Job Value: cfpnk4nnsade07159rsg -5.577
# EstimatorJob: cfpnk60mkkjip78pso8g
# Job Value: cfpnk60mkkjip78pso8g -5.314
# EstimatorJob: cfpnk7eh59a88pa0l10g
# Job Value: cfpnk7eh59a88pa0l10g -5.51
# EstimatorJob: cfpnk8omkkjip78pspi0
# Job Value: cfpnk8omkkjip78pspi0 -4.835000000000001
# EstimatorJob: cfpnkassiq6vn3fg653g
# Job Value: cfpnkassiq6vn3fg653g -6.088000000000001
# EstimatorJob: cfpnkbomkkjip78psqvg
# Job Value: cfpnkbomkkjip78psqvg -6.192
# {   'aux_operator_eigenvalues': None,
#     'cost_function_evals': 150,
#     'eigenstate': None,
#     'eigenvalue': -6.192,
#     'optimal_circuit': None,
#     'optimal_parameters': array([ 3.03505208,  5.01585854,  4.49714086,  5.373293  , -1.69388361,
#         2.65752663, -4.29746121, -2.04528639,  1.76424542,  3.45315195,
#         4.13331389,  2.48530781, -2.39379595,  4.23916985,  1.62576005,
#         1.38041481,  2.32806058, -5.48097384,  1.69076985,  1.61557864,
#        -3.65209312,  2.30295916,  3.70673492,  2.19484244,  3.11734435,
#        -2.78247672,  0.00659447,  6.56577588, -1.07802619, -0.86011326,
#        -2.53533077, -1.14688292,  0.74650109, -0.88466074,  2.85955194,
#         3.14828015,  3.22120976, -2.71692026, -0.07293092, -0.15488799,
#        -1.11583382, -2.08535918,  1.02597718, -3.81039455,  5.82417842,
#         4.79396756,  3.12117876,  4.01828683]),
#     'optimal_point': None,
#     'optimal_value': None,
#     'optimizer_evals': None,
#     'optimizer_result': None,
#     'optimizer_time': None} execution time (s): 1378.70

# %%
# # Setup Estimator (standard method)
# start = time()
# with Session(service=service, backend=backend) as session:
#     # Prepare primitive
#     rt_estimator = RuntimeEstimator(session=session)
#     # Set up algorithm
#     custom_vqe = CustomVQE(rt_estimator, ansatz_opt, optimizer, callback=callback_sim)
#     # Run algorithm
#     result = custom_vqe.compute_minimum_eigenvalue(ham_16)
# end = time()
# print(f'execution time (s): {end - start:.2f}')

# %%
plt.plot(intermediate_info_sim_backend, color='purple', lw=2, label='Simulated VQE')
plt.ylabel('Energy')
plt.xlabel('Iterations')
plt.axhline(y=gs_energy, color="tab:red", ls="--", lw=2, label="Target: " + str(gs_energy))
plt.legend()
plt.grid()
plt.show()

# %%
# Compute the relative error between the expected ground state energy and the measured
rel_error = rel_err(gs_energy, result.eigenvalue)

print(f'Expected ground state energy: {gs_energy:.10f}')
print(f'Computed ground state energy: {result.eigenvalue:.10f}')
print(f'Relative error: {rel_error:.8f}')
# Out:
# Expected ground state energy: -18.0000000000
# Computed ground state energy: -6.1920000000
# Relative error: 0.65600000

# %% [markdown]
# ## 3-2 Qiskit runtime Real backend (ibmq_guadalupe)
#
# If our `qiskit_ibm_runtime` code is working on the cloud simulator backend, we can simply change the backend to the ibmq_guadalupe to run on the real backend. This may take a couple hours. Your performance score will be determined by the calculated relative error between the true ground state energy of -18.0 and the measured energy from the real ibmq_guadalupe backend.

# %%
from qiskit_ibm_runtime import (QiskitRuntimeService, Session,
                                Estimator as RuntimeEstimator)
from qiskit import Aer

# service = QiskitRuntimeService(channel='ibm_quantum')
service = QiskitRuntimeService(
    channel='ibm_quantum',
    instance='ibm-q-community/ibmquantumawards/open-science-22',
)

backend = 'ibmq_guadalupe'

# %%
# Define a simple callback function
intermediate_info_real_backend = []
def callback_real(value):
        intermediate_info_real_backend.append(value)

# %%
import signal, time

from qiskit_ibm_runtime import Estimator, Session, Options
from qiskit.providers import JobStatus

def timeout_handler(signum, frame):
    raise Exception('Iteration timed out')
    
class RetryEstimator(Estimator):
    """RuntimeRetryEstimator class.
    
    This class inherits from Qiskit IBM Runtime's Estimator and overwrites its run method such that it retries calling it
    a maximum of 'max_retries' consecutive times, if it encounters one of the following randomly occuring errors:
    
    * An Estimator error (in this case "Job.ERROR" is printed, and the job is cancelled automatically)
    * A timeout error where the job either remains running or completes but does not return anything, for a time larger 
      than 'timeout' (in this case the job is cancelled by the patch and "Job.CANCELLED" is printed)
    * A creation error, where the job fails to be created because connection is lost between the runtime server and the
      quantum computer (in this case "Failed to create job." is printed). If this error occurs, the patch connects the user
      to a new Session (to be handled with care! also, this will unfortunately put the next job in the queue). 
    """
    
    def __init__(self, *args, max_retries: int = 5, timeout: int = 3600, **kwargs) -> None:
        super().__init__(*args, **kwargs)
        self.max_retries = max_retries
        self.timeout = timeout
        self.backend = super().session._backend
        signal.signal(signal.SIGALRM, timeout_handler)
    
    def run(self, circuits, observables, parameter_values, **kwargs):
        result = None
        for i in range(self.max_retries):
            try:
                job = super().run(circuits, observables, parameter_values, **kwargs)
                while job.status() in [JobStatus.INITIALIZING, JobStatus.QUEUED, JobStatus.VALIDATING]:
                    time.sleep(5) # Check every 5 seconds whether job status has changed
                signal.alarm(self.timeout) # Once job starts running, set timeout to 1 hour by default
                result = job.result()
                if result is not None:
                    signal.alarm(0) # reset timer
                    return job
            except Exception as e:
                print("\nSomething went wrong...")
                print(f"\n\nERROR MESSAGE:\n{e}\n\n")
                if 'job' in locals(): # Sometimes job fails to create
                    print(f"Job ID: {job.job_id}. Job status: {job.status()}.")
                    if job.status() not in [JobStatus.DONE, JobStatus.ERROR, JobStatus.CANCELLED]:
                        job.cancel()
                else:
                    print("Failed to create job.")
                print(f"Starting trial number {i+2}...\n")
                print(f"Creating new session...\n")
                signal.alarm(0) # reset timer
                super().session.close()
                self._session = Session(backend=self.backend)
        if result is None:
            raise RuntimeError(f"Program failed! Maximum number of retries ({self.max_retries}) exceeded")

# %%
options_ZNE = Options()
options_ZNE.execution.shots = 8900
options_ZNE.optimization_level = 0 # no optimization
options_ZNE.resilience_level = 2 # ZNE
options_ZNE.resilience.noise_factors = [np.pi/2, (np.pi/2)*2, (np.pi/2)*3]
options_ZNE.resilience.noise_amplifier = "LocalFoldingAmplifier"
options_ZNE.resilience.extrapolator = "QuadraticExtrapolator"

options = options_ZNE
#options = None
optimizer = SPSA(75)

# %%
init_data = result.optimal_parameters

# %%
# Setup Estimator with session error handling reconnection work around
start = time.time()
with Session(service=service, backend=backend) as session:
    # Prepare extended primitive
    rt_estimator = RetryEstimator(session=session, options=options)
    # set up algorithm
    custom_vqe = CustomVQE(rt_estimator, ansatz_opt, optimizer, callback=callback_real, init_data=init_data)
    # run algorithm
    result = custom_vqe.compute_minimum_eigenvalue(ham_16)
end = time.time()
print(f'execution time (s): {end - start:.2f}')
# Out:
# EstimatorJob: cfpjrqvnsade0713j47g
# Job Value: cfpjrqvnsade0713j47g -4.9523595505618
# EstimatorJob: cfpjtjnlq5soddt61af0
# Job Value: cfpjtjnlq5soddt61af0 -10.165393258426967
# EstimatorJob: cfpjtsvlq5soddt61ei0
# Job Value: cfpjtsvlq5soddt61ei0 -7.326292134831462
# EstimatorJob: cfpju5vlq5soddt61iag
# Job Value: cfpju5vlq5soddt61iag -9.7123595505618
# EstimatorJob: cfpjuf7lq5soddt61mbg
# Job Value: cfpjuf7lq5soddt61mbg -9.383370786516853
# EstimatorJob: cfpjuo7nsade0713kds0
# Job Value: cfpjuo7nsade0713kds0 -10.01573033707865
# EstimatorJob: cfpjv2eh59a88p9v0gq0
# Job Value: cfpjv2eh59a88p9v0gq0 -8.93752808988764
# EstimatorJob: cfpjvbvnsade0713kn00
# Job Value: cfpjvbvnsade0713kn00 -10.905168539325844
# EstimatorJob: cfpjvkuh59a88p9v0p6g
# Job Value: cfpjvkuh59a88p9v0p6g -9.526292134831461
# EstimatorJob: cfpjvu7nsade0713kv5g
# Job Value: cfpjvu7nsade0713kv5g -10.81932584269663
# EstimatorJob: cfpk078mkkjip78o6t00
# Job Value: cfpk078mkkjip78o6t00 -8.746067415730337
# EstimatorJob: cfpk0gnlq5soddt62i80
# Job Value: cfpk0gnlq5soddt62i80 -11.548314606741577
# EstimatorJob: cfpk0q4siq6vn3fegh00
# Job Value: cfpk0q4siq6vn3fegh00 -8.325842696629213
# EstimatorJob: cfpk13euqale1ribkf0g
# Job Value: cfpk13euqale1ribkf0g -6.487191011235957
# EstimatorJob: cfpk1cmh59a88p9v1hd0
# Job Value: cfpk1cmh59a88p9v1hd0 -10.724943820224716
# EstimatorJob: cfpk1lgmkkjip78o7i9g
# Job Value: cfpk1lgmkkjip78o7i9g -8.217078651685394
# EstimatorJob: cfpk1v7nsade0713lrh0
# Job Value: cfpk1v7nsade0713lrh0 -10.90561797752809
# EstimatorJob: cfpk28csiq6vn3feh5og
# Job Value: cfpk28csiq6vn3feh5og -9.14876404494382
# EstimatorJob: cfpk2hcsiq6vn3feh9og
# Job Value: cfpk2hcsiq6vn3feh9og -8.676404494382023
# EstimatorJob: cfpk2qnnsade0713m7u0
# Job Value: cfpk2qnnsade0713m7u0 -8.883146067415732
# EstimatorJob: cfpk33nnsade0713mbsg
# Job Value: cfpk33nnsade0713mbsg -9.12179775280899
# EstimatorJob: cfpk3cgmkkjip78o8big
# Job Value: cfpk3cgmkkjip78o8big -8.604044943820227
# EstimatorJob: cfpk3m6uqale1ribli1g
# Job Value: cfpk3m6uqale1ribli1g -7.8804494382022465
# EstimatorJob: cfpk3v4siq6vn3fehu70
# Job Value: cfpk3v4siq6vn3fehu70 -9.165842696629213
# EstimatorJob: cfpk48csiq6vn3fei2kg
# Job Value: cfpk48csiq6vn3fei2kg -8.771235955056182
# EstimatorJob: cfpk4hnnsade0713n0t0
# Job Value: cfpk4hnnsade0713n0t0 -9.910112359550565
# EstimatorJob: cfpk4r7nsade0713n4vg
# Job Value: cfpk4r7nsade0713n4vg -9.736629213483143
# EstimatorJob: cfpk546h59a88p9v365g
# Job Value: cfpk546h59a88p9v365g -8.525842696629214
# EstimatorJob: cfpk5dflq5soddt64lqg
# Job Value: cfpk5dflq5soddt64lqg -8.48
# EstimatorJob: cfpk5mnnsade0713nhq0
# Job Value: cfpk5mnnsade0713nhq0 -10.388764044943825
# EstimatorJob: cfpk5vomkkjip78o9j70
# Job Value: cfpk5vomkkjip78o9j70 -8.680000000000001
# EstimatorJob: cfpk68uuqale1ribmmog
# Job Value: cfpk68uuqale1ribmmog -9.535730337078654
# EstimatorJob: cfpk6i7lq5soddt656jg
# Job Value: cfpk6i7lq5soddt656jg -10.222921348314607
# EstimatorJob: cfpk6r8mkkjip78o9vng
# Job Value: cfpk6r8mkkjip78o9vng -8.522247191011239
# EstimatorJob: cfpk74mh59a88p9v425g
# Job Value: cfpk74mh59a88p9v425g -6.825617977528091
# EstimatorJob: cfpk7dssiq6vn3fejhv0
# Job Value: cfpk7dssiq6vn3fejhv0 -10.050786516853929
# EstimatorJob: cfpk7momkkjip78oac60
# Job Value: cfpk7momkkjip78oac60 -10.990112359550562
# EstimatorJob: cfpk804siq6vn3fejq9g
# Job Value: cfpk804siq6vn3fejq9g -7.33573033707865
# EstimatorJob: cfpk89fnsade0713oo3g
# Job Value: cfpk89fnsade0713oo3g -7.066966292134833
# EstimatorJob: cfpk8innsade0713oslg
# Job Value: cfpk8innsade0713oslg -10.778426966292137
# EstimatorJob: cfpk8romkkjip78oatsg
# Job Value: cfpk8romkkjip78oatsg -8.525842696629214
# EstimatorJob: cfpk956h59a88p9v4vi0
# Job Value: cfpk956h59a88p9v4vi0 -6.64134831460674
# EstimatorJob: cfpk9efnsade0713pa80
# Job Value: cfpk9efnsade0713pa80 -8.245842696629214
# EstimatorJob: cfpk9q0mkkjip78obcm0
# Job Value: cfpk9q0mkkjip78obcm0 -7.070561797752809
# EstimatorJob: cfpka3gmkkjip78obhgg
# Job Value: cfpka3gmkkjip78obhgg -8.350112359550565
# EstimatorJob: cfpkacomkkjip78obm6g
# Job Value: cfpkacomkkjip78obm6g -7.636853932584268
# EstimatorJob: cfpkamcsiq6vn3fel3u0
# Job Value: cfpkamcsiq6vn3fel3u0 -11.245842696629213
# EstimatorJob: cfpkavnlq5soddt676vg
# Job Value: cfpkavnlq5soddt676vg -9.637303370786517
# EstimatorJob: cfpkb9csiq6vn3feld90
# Job Value: cfpkb9csiq6vn3feld90 -8.440449438202247
# EstimatorJob: cfpkbiuuqale1ribp24g
# Job Value: cfpkbiuuqale1ribp24g -10.7447191011236
# EstimatorJob: cfpkbs7lq5soddt67jgg
# Job Value: cfpkbs7lq5soddt67jgg -8.96943820224719
# EstimatorJob: cfpkc5ksiq6vn3felr90
# Job Value: cfpkc5ksiq6vn3felr90 -9.60943820224719
# EstimatorJob: cfpkcevlq5soddt67rug
# Job Value: cfpkcevlq5soddt67rug -7.866067415730335
# EstimatorJob: cfpkcofnsade0713qs9g
# Job Value: cfpkcofnsade0713qs9g -6.669662921348315
# EstimatorJob: cfpkd1nlq5soddt684og
# Job Value: cfpkd1nlq5soddt684og -8.2
# EstimatorJob: cfpkdb7lq5soddt6894g
# Job Value: cfpkdb7lq5soddt6894g -4.410337078651687
# EstimatorJob: cfpkdkeh59a88p9v731g
# Job Value: cfpkdkeh59a88p9v731g -2.7321348314606753
# EstimatorJob: cfpkdtomkkjip78odd50
# Job Value: cfpkdtomkkjip78odd50 -3.2867415730337064
# EstimatorJob: cfpke78mkkjip78odhm0
# Job Value: cfpke78mkkjip78odhm0 -4.619325842696629
# EstimatorJob: cfpkegmh59a88p9v7gfg
# Job Value: cfpkegmh59a88p9v7gfg -2.53932584269663
# EstimatorJob: cfpkeq7nsade0713rqrg
# Job Value: cfpkeq7nsade0713rqrg -5.13752808988764
# EstimatorJob: cfpkf3flq5soddt692r0
# Job Value: cfpkf3flq5soddt692r0 -1.903820224719101
# EstimatorJob: cfpkfcuuqale1ribqpt0
# Job Value: cfpkfcuuqale1ribqpt0 -2.331685393258427
# EstimatorJob: cfpkfm6uqale1ribqtug
# Job Value: cfpkfm6uqale1ribqtug -5.103370786516853
# EstimatorJob: cfpkfvnlq5soddt69fkg
# Job Value: cfpkfvnlq5soddt69fkg -4.567191011235954
# EstimatorJob: cfpkg8vnsade0713sgv0
# Job Value: cfpkg8vnsade0713sgv0 -3.785168539325843
# EstimatorJob: cfpkgi6h59a88p9v8er0
# Job Value: cfpkgi6h59a88p9v8er0 -0.2242696629213472
# EstimatorJob: cfpkgromkkjip78oeqbg
# Job Value: cfpkgromkkjip78oeqbg -5.649887640449438
# EstimatorJob: cfpkh5flq5soddt6a100
# Job Value: cfpkh5flq5soddt6a100 -4.382921348314606
# EstimatorJob: cfpkhemuqale1ribrnk0
# Job Value: cfpkhemuqale1ribrnk0 -3.7083146067415744
# EstimatorJob: cfpkho4siq6vn3feog30
# Job Value: cfpkho4siq6vn3feog30 -3.6876404494382014
# EstimatorJob: cfpki1uh59a88p9v95hg
# Job Value: cfpki1uh59a88p9v95hg -4.031460674157304
# EstimatorJob: cfpkib8mkkjip78ofhf0
# Job Value: cfpkib8mkkjip78ofhf0 -4.939325842696631
# EstimatorJob: cfpkikvnsade0713tl40
# Job Value: cfpkikvnsade0713tl40 -4.67191011235955
# EstimatorJob: cfpkiu6h59a88p9v9i8g
# Job Value: cfpkiu6h59a88p9v9i8g -3.5159550561797754
# EstimatorJob: cfpkj7gmkkjip78ofucg
# Job Value: cfpkj7gmkkjip78ofucg -3.6750561797752788
# EstimatorJob: cfpkjguuqale1ribsmj0
# Job Value: cfpkjguuqale1ribsmj0 -3.5586516853932575
# EstimatorJob: cfpkjq7lq5soddt6b9gg
# Job Value: cfpkjq7lq5soddt6b9gg -5.19505617977528
# EstimatorJob: cfpkk3muqale1ribsvbg
# Job Value: cfpkk3muqale1ribsvbg -6.017528089887641
# EstimatorJob: cfpkkd6uqale1ribt3mg
# Job Value: cfpkkd6uqale1ribt3mg -3.377078651685393
# EstimatorJob: cfpkkmeuqale1ribt840
# Job Value: cfpkkmeuqale1ribt840 -5.2665168539325835
# EstimatorJob: cfpkkvssiq6vn3feq0h0
# Job Value: cfpkkvssiq6vn3feq0h0 -5.4368539325842695
# EstimatorJob: cfpkl9ksiq6vn3feq4tg
# Job Value: cfpkl9ksiq6vn3feq4tg -5.668314606741574
# EstimatorJob: cfpklj6h59a88p9vapn0
# Job Value: cfpklj6h59a88p9vapn0 -6.068764044943821
# EstimatorJob: cfpklsmuqale1ribtpug
# Job Value: cfpklsmuqale1ribtpug -6.2858426966292145
# EstimatorJob: cfpkm6eh59a88p9vb2v0
# Job Value: cfpkm6eh59a88p9vb2v0 -4.33573033707865
# EstimatorJob: cfpkmfnnsade0713vf0g
# Job Value: cfpkmfnnsade0713vf0g -7.0296629213483115
# EstimatorJob: cfpkmouuqale1ribu6ug
# Job Value: cfpkmouuqale1ribu6ug -5.355056179775281
# EstimatorJob: cfpkn24siq6vn3feqvjg
# Job Value: cfpkn24siq6vn3feqvjg -6.656179775280899
# EstimatorJob: cfpknbmh59a88p9vbk6g
# Job Value: cfpknbmh59a88p9vbk6g -6.44
# EstimatorJob: cfpknkuh59a88p9vbo30
# Job Value: cfpknkuh59a88p9vbo30 -4.9276404494382025
# EstimatorJob: cfpknueh59a88p9vbsug
# Job Value: cfpknueh59a88p9vbsug -8.217977528089888
# EstimatorJob: cfpko86uqale1ribusmg
# Job Value: cfpko86uqale1ribusmg -6.058426966292136
# EstimatorJob: cfpkohcsiq6vn3fermbg
# Job Value: cfpkohcsiq6vn3fermbg -5.906966292134835
# EstimatorJob: cfpkoqvlq5soddt6djsg
# Job Value: cfpkoqvlq5soddt6djsg -8.119550561797757
# EstimatorJob: cfpkp4gmkkjip78oip50
# Job Value: cfpkp4gmkkjip78oip50 -5.295730337078652
# EstimatorJob: cfpkphuuqale1ribvgk0
# Job Value: cfpkphuuqale1ribvgk0 -5.0898876404494375
# EstimatorJob: cfpkpr7nsade07141350
# Job Value: cfpkpr7nsade07141350 -7.069213483146068
# EstimatorJob: cfpkq4nlq5soddt6e7i0
# Job Value: cfpkq4nlq5soddt6e7i0 -7.506966292134831
# EstimatorJob: cfpkqe4siq6vn3fesj20
# Job Value: cfpkqe4siq6vn3fesj20 -5.107865168539326
# EstimatorJob: cfpkqn8mkkjip78ojgq0
# Job Value: cfpkqn8mkkjip78ojgq0 -5.045393258426968
# EstimatorJob: cfpkr0euqale1ric06k0
# Job Value: cfpkr0euqale1ric06k0 -8.395955056179773
# EstimatorJob: cfpkra6uqale1ric0bag
# Job Value: cfpkra6uqale1ric0bag -5.759999999999999
# EstimatorJob: cfpkrjeuqale1ric0gdg
# Job Value: cfpkrjeuqale1ric0gdg -6.6826966292134875
# EstimatorJob: cfpkrsgmkkjip78ok480
# Job Value: cfpkrsgmkkjip78ok480 -5.034606741573034
# EstimatorJob: cfpks6csiq6vn3fetg6g
# Job Value: cfpks6csiq6vn3fetg6g -6.568988764044943
# EstimatorJob: cfpksfomkkjip78okdp0
# Job Value: cfpksfomkkjip78okdp0 -5.115056179775279
# EstimatorJob: cfpksp0mkkjip78okikg
# Job Value: cfpksp0mkkjip78okikg -5.915505617977528
# EstimatorJob: cfpkt2nlq5soddt6fldg
# Job Value: cfpkt2nlq5soddt6fldg -5.440449438202248
# EstimatorJob: cfpktc7nsade07142s4g
# Job Value: cfpktc7nsade07142s4g -5.195505617977528
# EstimatorJob: cfpktlmuqale1ric1gqg
# Job Value: cfpktlmuqale1ric1gqg -5.405393258426967
# EstimatorJob: cfpktv7lq5soddt6g490
# Job Value: cfpktv7lq5soddt6g490 -6.35505617977528
# EstimatorJob: cfpku8ksiq6vn3feuhv0
# Job Value: cfpku8ksiq6vn3feuhv0 -4.50561797752809
# EstimatorJob: cfpkui0mkkjip78olgn0
# Job Value: cfpkui0mkkjip78olgn0 -6.768089887640451
# EstimatorJob: cfpkurnlq5soddt6ghl0
# Job Value: cfpkurnlq5soddt6ghl0 -7.823370786516853
# EstimatorJob: cfpkv4mh59a88p9vfb90
# Job Value: cfpkv4mh59a88p9vfb90 -5.7487640449438215
# EstimatorJob: cfpkve8mkkjip78oltt0
# Job Value: cfpkve8mkkjip78oltt0 -5.056179775280898
# EstimatorJob: cfpkvnnnsade071441ig
# Job Value: cfpkvnnnsade071441ig -6.762247191011234
# EstimatorJob: cfpl00uh59a88p9vfntg
# Job Value: cfpl00uh59a88p9vfntg -4.483595505617977
# EstimatorJob: cfpl0aflq5soddt6h6hg
# Job Value: cfpl0aflq5soddt6h6hg -8.293932584269662
# EstimatorJob: cfpl0jgmkkjip78omdl0
# Job Value: cfpl0jgmkkjip78omdl0 -6.617977528089887
# EstimatorJob: cfpl0t6uqale1ric31o0
# Job Value: cfpl0t6uqale1ric31o0 -6.687640449438203
# EstimatorJob: cfpl16ksiq6vn3fevut0
# Job Value: cfpl16ksiq6vn3fevut0 -6.700224719101124
# EstimatorJob: cfpl1g4siq6vn3ff0330
# Job Value: cfpl1g4siq6vn3ff0330 -6.687191011235956
# EstimatorJob: cfpl1pnlq5soddt6hqig
# Job Value: cfpl1pnlq5soddt6hqig -6.347865168539325
# EstimatorJob: cfpl22omkkjip78on3fg
# Job Value: cfpl22omkkjip78on3fg -7.156404494382022
# EstimatorJob: cfpl2cgmkkjip78on7m0
# Job Value: cfpl2cgmkkjip78on7m0 -5.542921348314606
# EstimatorJob: cfpl2luuqale1ric3qbg
# Job Value: cfpl2luuqale1ric3qbg -7.693483146067413
# EstimatorJob: cfpl2uuuqale1ric3ujg
# Job Value: cfpl2uuuqale1ric3ujg -5.939775280898876
# EstimatorJob: cfpl38euqale1ric425g
# Job Value: cfpl38euqale1ric425g -8.458876404494385
# EstimatorJob: cfpl3hssiq6vn3ff115g
# Job Value: cfpl3hssiq6vn3ff115g -9.751460674157302
# EstimatorJob: cfpl3rmuqale1ric4aq0
# Job Value: cfpl3rmuqale1ric4aq0 -6.882247191011236
# EstimatorJob: cfpl456uqale1ric4erg
# Job Value: cfpl456uqale1ric4erg -9.076853932584271
# EstimatorJob: cfpl4eeh59a88p9vhm80
# Job Value: cfpl4eeh59a88p9vhm80 -8.068314606741573
# EstimatorJob: cfpl4nnlq5soddt6j33g
# Job Value: cfpl4nnlq5soddt6j33g -8.573483146067417
# EstimatorJob: cfpl51eh59a88p9vhu6g
# Job Value: cfpl51eh59a88p9vhu6g -8.538876404494385
# EstimatorJob: cfpl5amh59a88p9vi280
# Job Value: cfpl5amh59a88p9vi280 -8.711910112359552
# EstimatorJob: cfpl5k0mkkjip78oon40
# Job Value: cfpl5k0mkkjip78oon40 -8.207640449438202
# EstimatorJob: cfpl60vnsade07146s80
# Job Value: cfpl60vnsade07146s80 -8.690786516853935
# EstimatorJob: cfpl6aksiq6vn3ff2a80
# Job Value: cfpl6aksiq6vn3ff2a80 -7.517752808988762
# EstimatorJob: cfpl6kfnsade0714755g
# Job Value: cfpl6kfnsade0714755g -9.049438202247192
# EstimatorJob: cfpl6tflq5soddt6k1hg
# Job Value: cfpl6tflq5soddt6k1hg -7.10247191011236
# EstimatorJob: cfpl796h59a88p9vitrg
# Job Value: cfpl796h59a88p9vitrg -6.572584269662922
# EstimatorJob: cfpl7svlq5soddt6kfi0
# Job Value: cfpl7svlq5soddt6kfi0 -9.686741573033713
# EstimatorJob: cfpl86fnsade07147s5g
# Job Value: cfpl86fnsade07147s5g -9.132134831460673
# EstimatorJob: cfpl8fnlq5soddt6kong
# Job Value: cfpl8fnlq5soddt6kong -8.633258426966291
# EstimatorJob: cfpl8p7lq5soddt6ksqg
# Job Value: cfpl8p7lq5soddt6ksqg -8.413033707865168
# EstimatorJob: cfpl92csiq6vn3ff3ipg
# Job Value: cfpl92csiq6vn3ff3ipg -8.846741573033711
# EstimatorJob: cfpl9heh59a88p9vjv7g
# Job Value: cfpl9heh59a88p9vjv7g -7.946966292134834
# EstimatorJob: cfpl9quh59a88p9vk3eg
# Job Value: cfpl9quh59a88p9vk3eg -6.613932584269665
# EstimatorJob: cfpla4euqale1ric743g
# Job Value: cfpla4euqale1ric743g -8.000898876404495
# EstimatorJob: cfpladomkkjip78oqtvg
# Job Value: cfpladomkkjip78oqtvg -7.714157303370789
# EstimatorJob: cfplan8mkkjip78or25g
# Job Value: cfplan8mkkjip78or25g -8.18741573033708
# EstimatorJob: cfplbbflq5soddt6m1gg
# Job Value: cfplbbflq5soddt6m1gg -7.492584269662923
# EstimatorJob: cfplbkmuqale1ric7pcg
# Job Value: cfplbkmuqale1ric7pcg -7.005842696629215
# EstimatorJob: cfplbu8mkkjip78ork2g
# Job Value: cfplbu8mkkjip78ork2g -8.593707865168538
# EstimatorJob: cfplc7nlq5soddt6mdq0
# Job Value: cfplc7nlq5soddt6mdq0 -7.999101123595507
# EstimatorJob: cfplck4siq6vn3ff573g
# Job Value: cfplck4siq6vn3ff573g -9.101573033707867
# EstimatorJob: cfpld08mkkjip78os3kg
# Job Value: cfpld08mkkjip78os3kg -8.643146067415733
# EstimatorJob: cfpldcuuqale1ric8hug
# Job Value: cfpldcuuqale1ric8hug -6.646741573033708
# EstimatorJob: cfpldpeh59a88p9vlqdg
# Job Value: cfpldpeh59a88p9vlqdg -7.7334831460674165
# EstimatorJob: cfple56uqale1ric8s80
# Job Value: cfple56uqale1ric8s80 -8.96134831460674
# EstimatorJob: cfpleh6uqale1ric919g
# Job Value: cfpleh6uqale1ric919g -8.16494382022472
# EstimatorJob: cfplescsiq6vn3ff67hg
# Job Value: cfplescsiq6vn3ff67hg -8.591011235955058
# EstimatorJob: cfplf7uuqale1ric9aug
# Job Value: cfplf7uuqale1ric9aug -9.213483146067418
# EstimatorJob: cfplfjcsiq6vn3ff6iag
# Job Value: cfplfjcsiq6vn3ff6iag -7.858426966292135
# EstimatorJob: cfplfsuuqale1ric9kdg
# Job Value: cfplfsuuqale1ric9kdg -7.9325842696629225
# EstimatorJob: cfplg6uh59a88p9vmt20
# Job Value: cfplg6uh59a88p9vmt20 -8.311460674157301
# EstimatorJob: cfplgg7nsade0714bjo0
# Job Value: cfplgg7nsade0714bjo0 -8.717752808988765
# EstimatorJob: cfplgpgmkkjip78otqf0
# Job Value: cfplgpgmkkjip78otqf0 -7.473707865168543
# EstimatorJob: cfplh2ssiq6vn3ff78l0
# Job Value: cfplh2ssiq6vn3ff78l0 -7.52943820224719
# EstimatorJob: cfplhc6h59a88p9vnee0
# Job Value: cfplhc6h59a88p9vnee0 -9.028764044943822
# EstimatorJob: cfplhluh59a88p9vnj1g
# Job Value: cfplhluh59a88p9vnj1g -8.171685393258425
# EstimatorJob: cfplhv7nsade0714c8s0
# Job Value: cfplhv7nsade0714c8s0 -9.087640449438203
# EstimatorJob: cfpli9uh59a88p9vnse0
# Job Value: cfpli9uh59a88p9vnse0 -9.426516853932588
# EstimatorJob: cfplijnnsade0714cic0
# Job Value: cfplijnnsade0714cic0 -8.186067415730339
# EstimatorJob: cfplisuh59a88p9vo4c0
# Job Value: cfplisuh59a88p9vo4c0 -9.499775280898879
# EstimatorJob: cfplj6ssiq6vn3ff87og
# Job Value: cfplj6ssiq6vn3ff87og -8.247191011235955
# EstimatorJob: cfpljgeuqale1ricb76g
# Job Value: cfpljgeuqale1ricb76g -8.763595505617978
# EstimatorJob: cfpljseh59a88p9voib0
# Job Value: cfpljseh59a88p9voib0 -9.631910112359552
# EstimatorJob: cfplk5uh59a88p9vomhg
# Job Value: cfplk5uh59a88p9vomhg -7.488539325842697
# EstimatorJob: cfplkfflq5soddt6q0d0
# Job Value: cfplkfflq5soddt6q0d0 -8.191910112359551
# EstimatorJob: cfplkossiq6vn3ff8ul0
# Job Value: cfplkossiq6vn3ff8ul0 -8.060224719101127
# EstimatorJob: cfpll2csiq6vn3ff933g
# Job Value: cfpll2csiq6vn3ff933g -9.672808988764046
# EstimatorJob: cfpllbksiq6vn3ff97q0
# Job Value: cfpllbksiq6vn3ff97q0 -9.16808988764045
# EstimatorJob: cfpllnfnsade0714e15g
# Job Value: cfpllnfnsade0714e15g -8.605842696629214
# EstimatorJob: cfplm0uh59a88p9vpg90
# Job Value: cfplm0uh59a88p9vpg90 -7.735280898876406
# EstimatorJob: cfplmamuqale1riccetg
# Job Value: cfplmamuqale1riccetg -9.58741573033708
# EstimatorJob: cfplmjssiq6vn3ff9qn0
# Job Value: cfplmjssiq6vn3ff9qn0 -9.411235955056183
# EstimatorJob: cfplmtmuqale1riccnm0
# Job Value: cfplmtmuqale1riccnm0 -8.213483146067416
# EstimatorJob: cfpln7euqale1riccs70
# Job Value: cfpln7euqale1riccs70 -9.835505617977528
# EstimatorJob: cfplngmh59a88p9vq4v0
# Job Value: cfplngmh59a88p9vq4v0 -8.091235955056181
# EstimatorJob: cfplnpvnsade0714f0g0
# Job Value: cfplnpvnsade0714f0g0 -8.747865168539327
# EstimatorJob: cfplo37lq5soddt6rkc0
# Job Value: cfplo37lq5soddt6rkc0 -7.828764044943821
# EstimatorJob: cfplocksiq6vn3ffakng
# Job Value: cfplocksiq6vn3ffakng -9.448539325842697
# EstimatorJob: cfploluh59a88p9vqlr0
# Job Value: cfploluh59a88p9vqlr0 -9.982921348314605
# EstimatorJob: cfplovcsiq6vn3ffatjg
# Job Value: cfplovcsiq6vn3ffatjg -8.812584269662924
# EstimatorJob: cfplp8ssiq6vn3ffb210
# Job Value: cfplp8ssiq6vn3ffb210 -9.64674157303371
# EstimatorJob: cfplpi7lq5soddt6s8o0
# Job Value: cfplpi7lq5soddt6s8o0 -9.774831460674159
# EstimatorJob: cfplprksiq6vn3ffba3g
# Job Value: cfplprksiq6vn3ffba3g -9.922247191011236
# EstimatorJob: cfplq4uuqale1rice5jg
# Job Value: cfplq4uuqale1rice5jg -10.570786516853932
# execution time (s): 8013.61

# %%
# # Setup Estimator
# start = time()
# with Session(service=service, backend=backend) as session:
#     # Prepare primitive
#     rt_estimator = RuntimeEstimator(session=session)
#     # set up algorithm
#     custom_vqe = CustomVQE(rt_estimator, ansatz_opt, optimizer, callback=callback_real)
#     # run algorithm
#     result = custom_vqe.compute_minimum_eigenvalue(ham_16)
# end = time()
# print(f'execution time (s): {end - start:.2f}')

# %%
plt.plot(intermediate_info_real_backend, color='purple', lw=2, label='VQE')
plt.ylabel('Energy')
plt.xlabel('Iterations')
plt.axhline(y=gs_energy, color="tab:red", ls="--", lw=2, label="Target: " + str(gs_energy))
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## 3-3 Performance Score
# Compute the relative error between the expected ground state energy and the VQE result.

# %%
# Compute the relative error between the expected ground state energy and the measured
computed_gse = intermediate_info_real_backend[-1]

print(f'Expected ground state energy: {gs_energy:.8f}')
print(f'Computed ground state energy: {computed_gse:.8f}')
print(f'Relative error: {100 * rel_err(gs_energy, computed_gse):.8f} %')
# Out:
# Expected ground state energy: -18.00000000
# Computed ground state energy: -10.57078652
# Relative error: 41.27340824 %

# %% [markdown]
# # Considerations
# Feeling stuck? Below are a list of questions and considerations to help spark new ideas for your VQE implementation.
#
# **Ansatz.** Carefully consult research literature for the best approach of ansatz selection. How might errors affect your ansatz? How many parameters are needed to reach the ground state? What properties of the Hamiltonian could help simplify the ansatz?
#
# **Classical optimizer.** What optimizer will pair well with for your choice of ansatz and measurement parameters? What noise do you expect from the quantum computer, and what noise sensitivity can the classical optimizer withstand? How many iterations will be needed?
#
# **Initial state/point.** Is there an initial quantum state that really helps things get going? What about a starting point for the circuit parameters? Does the VQE give the same results for different initial parameter values?
#
# **Number of measurements.** How does the number of shots affect the VQE's convergence to the ground state energy? The expectation value of the Hamiltonian is a sum of the expectation values of each of the 54 terms. What is the least number of circuit executions necessary to compute the expectation value of the Hamiltonian? What is the optimal number of circuit executions for stable convergence?
#
# **Many qubits.** Working with larger numbers of qubits is its own challenge. For example, what's a concise way of writing down or even visualizing the 4096 digit ground state? What methods and techniques will not scale well? What techniques would scale well if this VQE were to be done on a larger system? How can you reduce your execution time of the real device?
#
# **Error mitigation.** What errors are most prevalent, and how can you reduce them efficiently? What error mitigation techniques will scale well?

# %%
import qiskit_ibm_runtime
qiskit_ibm_runtime.version.get_version_info()

# %%
import qiskit.tools.jupyter
# %qiskit_version_table
